# %%
# import data manipulation libraries
import numpy as np
import pandas as pd
# import file acquisition tools
import os
import requests
# import splitting function
from sklearn.model_selection import train_test_split

# %%
def acquire_austin_animal_shelter_data():
    '''
    This function will read in austin animal shelter intake and outcome data via csv,
    it will then rename to the column names to lowercase and remove spaces,
    it will then combine the csv files into one DataFrame and return the combined df.
    '''
    # set the filenames we are looking for
    intake_filename = 'Austin_Animal_Center_Intakes.csv'
    outcome_filename = 'Austin_Animal_Center_Outcomes.csv'
    # set the api paths
    intake_api = 'https://data.austintexas.gov/resource/wter-evkm.json'
    outcome_api = 'https://data.austintexas.gov/resource/9t4d-g238.json'
    
    # check if intake and outcome files exist in the local directory
    if os.path.exists(intake_filename):
        # read in csv files for intakes for animals
        intakes = pd.read_csv(intake_filename)
    else:
        # if the intake file does not exist locally, then download the data via api
        intakes = pd.DataFrame(request.json())
        intakes.datetime = pd.to_datetime(intakes.datetime)
    
    # check if outcome file exist in the local directory
    if os.path.exists(outcome_filename):
        # read in csv files for outcomes for animals
        outcomes = pd.read_csv(outcome_filename)
    else:
        # if the intake file does not exist locally, then download the data via api
        outcomes = pd.DataFrame(request.json())
        outcomes.datetime = pd.to_datetime(outcomes.datetime)
        
    # rename column names to lowercase and remove spaces
    intakes.columns = intakes.columns.str.lower().str.replace(' ','_').to_list()
    outcomes.columns = outcomes.columns.str.lower().str.replace(' ','_').to_list()
    # merge dataframes into one
    animals = pd.merge(left=intakes, right=outcomes, how='inner', 
                       on='animal_id', suffixes=('_in','_out'))
    
    # return the combined dataframe
    return animals

# %%
def prepare_austin_animal_shelter(animals):
    '''
    this function will prepare the animal shelter data by changing the datetime_in and out
    into datatime dtype, it will then drop the redundant color_out, breed_out, name_out
    and animal_type_out columns and rename the remaining columns, it will then
    return the modified dataframe.
    '''
    # change dtypes to datetime
    animals['datetime_in'] = pd.to_datetime(animals.datetime_in)
    animals['datetime_out'] = pd.to_datetime(animals.datetime_out)
    # remove redundant columns
    animals = animals.drop(columns=['color_out', 'breed_out', 
                                    'name_out', 'animal_type_out'])
    # rename remaining columns
    animals = animals.rename(columns={'color_in':'color', 
                                      'breed_in':'breed', 'name_in':'name',
                                      'animal_type_in':'animal_type'})
    # drop redundaant columns for month_year
#     animals = animals.drop(columns=['monthyear_in', 'monthyear_out'])
    # remove the 2 rows with nullsin the sex_upon_intake column, 
    # 1 of which is a test row
    animals = animals[animals.sex_upon_intake.isna() == False]
    
    # create a new column with binned outcome_type
    animals['outcome'] = np.where(animals.outcome_type == 'Adoption', 'adopted',
                          np.where(animals.outcome_type == 'Return to Owner', 'returned',
                          np.where(animals.outcome_type == 'Transfer', 'transfered',
                          np.where(animals.outcome_type == 'Euthanasia', 'death',
                          np.where(animals.outcome_type == 'Rto-Adopt', 'returned',
                          np.where(animals.outcome_type == 'Died', 'death',
                          np.where(animals.outcome_type == 'Disposal', 'death',
                          np.where(animals.outcome_type == 'Missing', 'unknown',
                          np.where(animals.outcome_type == 'Stolen', 'unknown',
                          np.where(animals.outcome_type == 'Relocate', 'transfered',
                          np.where(animals.outcome_type.isnull() == True, 'unknown', ''
                                  )))))))))))
    # return the modified dataframe
    return animals

# %%
def split_austin_animal_shelter(df):
    '''
    This function splits a dataframe into 
    train, validate, and test in order to explore the data and to create and validate models. 
    It takes in a dataframe and contains an integer for setting a seed for replication. 
    Test is 20% of the original dataset. The remaining 80% of the dataset is 
    divided between valiidate and train, with validate being .30*.80= 24% of 
    the original dataset, and train being .70*.80= 56% of the original dataset. 
    The function returns, train, validate and test dataframes. 
    '''
    # Here we are spliting train into .8 of the original dataset. 
    # and test into 20% of the original dataset.
    train, test = train_test_split(df, test_size = .2, random_state=123)
    # here we assign validate to be .3 of the train dataset 
    train, validate = train_test_split(train, test_size=.3, random_state=123)
    # returns train validate and test dataframes
    return train, validate, test

# %%
def wrangle_austin_animal_shelter():
    '''
    This function will perform acquisition, preparation and train, validate, test
    split into one function call and will return the cleaned dataframe along with 
    the train, validate and test dataframes.
    '''
    # check if a cached file of the dataset exists in the local directory
    
    # acquire data from csv files
    animals = acquire_austin_animal_shelter_data()
    # prepare the data
    animals = prepare_austin_animal_shelter(animals)
    # split data into train, validate and test groups
    train, validate, test = split_austin_animal_shelter(animals)
    # return all the data
    return animals, train, validate, test

# %%
intakes = pd.read_csv('Austin_Animal_Center_Intakes.csv')
outcomes = pd.read_csv('Austin_Animal_Center_Outcomes.csv')

# %%
intake_api = 'https://data.austintexas.gov/resource/wter-evkm.json'
outcome_api = 'https://data.austintexas.gov/resource/9t4d-g238.json'

# %%
requests.get(intake_api)
# Out:
# <Response [200]>

# %%
request = requests.get(intake_api)
request.json()
# Out:
# [{'animal_id': 'A665644',
#   'datetime': '2013-10-21T07:59:00.000',
#   'datetime2': '2013-10-21T07:59:00.000',
#   'found_location': 'Austin (TX)',
#   'intake_type': 'Stray',
#   'intake_condition': 'Sick',
#   'animal_type': 'Cat',
#   'sex_upon_intake': 'Intact Female',
#   'age_upon_intake': '4 weeks',
#   'breed': 'Domestic Shorthair Mix',
#   'color': 'Calico'},
#  {'animal_id': 'A665739',
#   'name': '*Alana',
#   'datetime': '2013-10-22T11:11:00.000',
#   'datetime2': '2013-10-22T11:11:00.000',
#   'found_location': 'Austin (TX)',
#   'intake_type': 'Stray',
#   'intake_condition': 'Normal',
#   'animal_type': 'Cat',
#   'sex_upon_intake': 'Intact Female',
#   'age_upon_intake': '1 month',
#   'breed': 'Domestic Medium Hair Mix',
#   'color': 'Black'},
#  {'animal_id': 'A665763',
#   'datetime': '2013-10-22T15:10:00.000',
#   'datetime2': '2013-10-22T15:10:00.000',
#   'found_location': 'E Riverside Dr/Royal Crest Dr in Austin (TX)',
#   'intake_type': 'Stray',
#   'intake_condition': 'Normal',
#   'animal_type': 'Dog',
#   'sex_upon_intake': 'Intact Male',
#   'age_upon_intake': '4 months',
#   'breed': 'Cairn Terrier Mix',
#   'color': 'Tan/White'},
#  {'animal_id': 'A379998',
#   'name': 'Disciple',
#   'datetime': '2013-10-23T11:42:00.000',
#   'datetime2': '2013-10-23T11:42:00.000',
#   'found_location': '51St And Grover in Austin (TX)',
#   'intake_type': 'Stray',
#   'intake_condition': 'Normal',
#   'animal_type': 'Dog',
#   'sex_upon_intake': 'Intact Male',
#   'age_upon_intake': '10 years',
#   'breed': 'Pit Bull',
#   'color': 'Black'},
#  {'animal_id': 'A634503',
#   'name': 'Otter',
#   'datetime': '2013-10-01T14:49:00.000',
#   'datetime2': '2013-10-01T14:49:00.000',
#   'found_location': 'Manor (TX)',
#   'intake_type': 'Owner Surrender',
#   'intake_condition': 'Normal',
#   'animal_type': 'Dog',
#   'sex_upon_intake': 'Spayed Female',
#   'age_upon_intake': '2 years',
#   'breed': 'Norfolk Terrier Mix',
#   'color': 'Tan'},
#  {'animal_id': 'A665496',
#   'name': 'Mikey',
#   'datetime': '2013-10-18T18:07:00.000',
#   'datetime2': '2013-10-18T18:07:00.000',
#   'found_location': '12001 Metric Blvd in Austin (TX)',
#   'intake_type': 'Stray',
#   'intake_condition': 'Normal',
#   'animal_type': 'Cat',
#   'sex_upon_intake': 'Neutered Male',
#   'age_upon_intake': '3 years',
#   'breed': 'Bengal',
#   'color': 'Brown Tiger'},
#  {'animal_id': 'A665002',
#   'datetime': '2013-10-12T11:45:00.000',
#   'datetime2': '2013-10-12T11:45:00.000',
#   'found_location': '509 E Todd Lane in Austin (TX)',
#   'intake_type': 'Stray',
#   'intake_condition': 'Normal',
#   'animal_type': 'Dog',
#   'sex_upon_intake': 'Intact Female',
#   'age_upon_intake': '1 week',
#   'breed': 'Australian Cattle Dog Mix',
#   'color': 'Sable/White'},
#  {'animal_id': 'A664936',
#   'name': '*Jester',
#   'datetime': '2013-10-11T11:20:00.000',
#   'datetime2': '2013-10-11T11:20:00.000',
#   'found_location': '501 U.S. 183 in Austin (TX)',
#   'intake_type': 'Stray',
#   'intake_condition': 'Normal',
#   'animal_type': 'Cat',
#   'sex_upon_intake': 'Intact Male',
#   'age_upon_intake': '1 month',
#   'breed': 'Domestic Medium Hair Mix',
#   'color': 'Brown Tabby'},
#  {'animal_id': 'A664235',
#   'datetime': '2013-10-01T08:33:00.000',
#   'datetime2': '2013-10-01T08:33:00.000',
#   'found_location': 'Abia in Austin (TX)',
#   'intake_type': 'Stray',
#   'intake_condition': 'Normal',
#   'animal_type': 'Cat',
#   'sex_upon_intake': 'Unknown',
#   'age_upon_intake': '1 week',
#   'breed': 'Domestic Shorthair Mix',
#   'color': 'Orange/White'},
#  {'animal_id': 'A666101',
#   'datetime': '2013-10-26T18:33:00.000',
#   'datetime2': '2013-10-26T18:33:00.000',
#   'found_location': 'Payne in Austin (TX)',
#   'intake_type': 'Wildlife',
#   'intake_condition': 'Injured',
#   'animal_type': 'Other',
#   'sex_upon_intake': 'Unknown',
#   'age_upon_intake': '0 years',
#   'breed': 'Squirrel Mix',
#   'color': 'Gray/Brown'},
#  {'animal_id': 'A664830',
#   'datetime': '2013-10-09T15:34:00.000',
#   'datetime2': '2013-10-09T15:34:00.000',
#   'found_location': '15043 Savannah Heights in Travis (TX)',
#   'intake_type': 'Wildlife',
#   'intake_condition': 'Sick',
#   'animal_type': 'Other',
#   'sex_upon_intake': 'Unknown',
#   'age_upon_intake': '1 year',
#   'breed': 'Raccoon Mix',
#   'color': 'Brown/Black'},
#  {'animal_id': 'A664262',
#   'datetime': '2013-10-01T11:45:00.000',
#   'datetime2': '2013-10-01T11:45:00.000',
#   'found_location': '4915 Yager Ln in Austin (TX)',
#   'intake_type': 'Stray',
#   'intake_condition': 'Normal',
#   'animal_type': 'Cat',
#   'sex_upon_intake': 'Intact Male',
#   'age_upon_intake': '1 weeks',
#   'breed': 'Domestic Shorthair Mix',
#   'color': 'Orange Tabby'},
#  {'animal_id': 'A664887',
#   'name': '*Gia',
#   'datetime': '2013-10-10T13:48:00.000',
#   'datetime2': '2013-10-10T13:48:00.000',
#   'found_location': '1901 Onion Creek Pkwy in Austin (TX)',
#   'intake_type': 'Stray',
#   'intake_condition': 'Normal',
#   'animal_type': 'Cat',
#   'sex_upon_intake': 'Intact Female',
#   'age_upon_intake': '1 month',
#   'breed': 'Domestic Shorthair Mix',
#   'color': 'Black'},
#  {'animal_id': 'A665800',
#   'name': '*Precious',
#   'datetime': '2013-10-23T11:08:00.000',
#   'datetime2': '2013-10-23T11:08:00.000',
#   'found_location': 'Austin (TX)',
#   'intake_type': 'Owner Surrender',
#   'intake_condition': 'Normal',
#   'animal_type': 'Cat',
#   'sex_upon_intake': 'Intact Female',
#   'age_upon_intake': '3 months',
#   'breed': 'Domestic Shorthair Mix',
#   'color': 'Tortie'},
#  {'animal_id': 'A645345',
#   'name': 'Honey',
#   'datetime': '2013-10-01T17:54:00.000',
#   'datetime2': '2013-10-01T17:54:00.000',
#   'found_location': 'Austin (TX)',
#   'intake_type': 'Owner Surrender',
#   'intake_condition': 'Normal',
#   'animal_type': 'Dog',
#   'sex_upon_intake': 'Spayed Female',
#   'age_upon_intake': '1 year',
#   'breed': 'Pit Bull Mix',
#   'color': 'Brown/White'},
#  {'animal_id': 'A665817',
#   'datetime': '2013-10-23T12:07:00.000',
#   'datetime2': '2013-10-23T12:07:00.000',
#   'found_location': 'Austin (TX)',
#   'intake_type': 'Stray',
#   'intake_condition': 'Normal',
#   'animal_type': 'Dog',
#   'sex_upon_intake': 'Intact Male',
#   'age_upon_intake': '2 months',
#   'breed': 'Chihuahua Shorthair Mix',
#   'color': 'White/Chocolate'},
#  {'animal_id': 'A665706',
#   'datetime': '2013-10-21T18:06:00.000',
#   'datetime2': '2013-10-21T18:06:00.000',
#   'found_location': '43 Rainey St in Austin (TX)',
#   'intake_type': 'Wildlife',
#   'intake_condition': 'Normal',
#   'animal_type': 'Other',
#   'sex_upon_intake': 'Unknown',
#   'age_upon_intake': '1 year',
#   'breed': 'Bat Mix',
#   'color': 'Brown'},
#  {'animal_id': 'A665615',
#   'name': 'Abby',
#   'datetime': '2013-10-20T12:01:00.000',
#   'datetime2': '2013-10-20T12:01:00.000',
#   'found_location': '4708 Marblehead in Austin (TX)',
#   'intake_type': 'Stray',
#   'intake_condition': 'Normal',
#   'animal_type': 'Dog',
#   'sex_upon_intake': 'Spayed Female',
#   'age_upon_intake': '8 years',
#   'breed': 'Border Collie/Labrador Retriever',
#   'color': 'Chocolate/White'},
#  {'animal_id': 'A664468',
#   'name': '*Jesse',
#   'datetime': '2013-10-03T18:45:00.000',
#   'datetime2': '2013-10-03T18:45:00.000',
#   'found_location': '23107 Fulkes Ln. in Austin (TX)',
#   'intake_type': 'Stray',
#   'intake_condition': 'Normal',
#   'animal_type': 'Dog',
#   'sex_upon_intake': 'Intact Male',
#   'age_upon_intake': '1 year',
#   'breed': 'Chesa Bay Retr Mix',
#   'color': 'Tan/White'},
#  {'animal_id': 'A664770',
#   'name': '*Frosty',
#   'datetime': '2013-10-08T17:46:00.000',
#   'datetime2': '2013-10-08T17:46:00.000',
#   'found_location': '6808 Felipe Dr in Austin (TX)',
#   'intake_type': 'Stray',
#   'intake_condition': 'Normal',
#   'animal_type': 'Dog',
#   'sex_upon_intake': 'Intact Female',
#   'age_upon_intake': '3 months',
#   'breed': 'Australian Cattle Dog Mix',
#   'color': 'Blue Merle/Cream'},
#  {'animal_id': 'A665923',
#   'name': 'Willow',
#   'datetime': '2013-10-24T17:57:00.000',
#   'datetime2': '2013-10-24T17:57:00.000',
#   'found_location': 'Austin (TX)',
#   'intake_type': 'Public Assist',
#   'intake_condition': 'Normal',
#   'animal_type': 'Dog',
#   'sex_upon_intake': 'Spayed Female',
#   'age_upon_intake': '1 year',
#   'breed': 'German Shepherd/Labrador Retriever',
#   'color': 'Red'},
#  {'animal_id': 'A612451',
#   'name': 'Waffles',
#   'datetime': '2013-10-26T13:56:00.000',
#   'datetime2': '2013-10-26T13:56:00.000',
#   'found_location': '111 E St Johns Ave in Austin (TX)',
#   'intake_type': 'Stray',
#   'intake_condition': 'Normal',
#   'animal_type': 'Dog',
#   'sex_upon_intake': 'Neutered Male',
#   'age_upon_intake': '2 years',
#   'breed': 'Cairn Terrier Mix',
#   'color': 'Tan'},
#  {'animal_id': 'A663673',
#   'name': 'Frosty',
#   'datetime': '2013-10-02T14:27:00.000',
#   'datetime2': '2013-10-02T14:27:00.000',
#   'found_location': 'Travis (TX)',
#   'intake_type': 'Owner Surrender',
#   'intake_condition': 'Normal',
#   'animal_type': 'Dog',
#   'sex_upon_intake': 'Intact Male',
#   'age_upon_intake': '4 years',
#   'breed': 'Great Pyrenees Mix',
#   'color': 'White'},
#  {'animal_id': 'A665398',
#   'name': 'Haven',
#   'datetime': '2013-10-17T12:26:00.000',
#   'datetime2': '2013-10-17T12:26:00.000',
#   'found_location': 'Austin (TX)',
#   'intake_type': 'Owner Surrender',
#   'intake_condition': 'Normal',
#   'animal_type': 'Cat',
#   'sex_upon_intake': 'Intact Female',
#   'age_upon_intake': '1 month',
#   'breed': 'Domestic Shorthair Mix',
#   'color': 'White/Blue'},
#  {'animal_id': 'A665856',
#   'name': 'Mocha',
#   'datetime': '2013-10-23T16:11:00.000',
#   'datetime2': '2013-10-23T16:11:00.000',
#   'found_location': 'Montopolis/183 in Austin (TX)',
#   'intake_type': 'Stray',
#   'intake_condition': 'Normal',
#   'animal_type': 'Dog',
#   'sex_upon_intake': 'Intact Female',
#   'age_upon_intake': '9 months',
#   'breed': 'Pit Bull Mix',
#   'color': 'Chocolate'},
#  {'animal_id': 'A665866',
#   'name': 'Rifle',
#   'datetime': '2013-10-23T18:14:00.000',
#   'datetime2': '2013-10-23T18:14:00.000',
#   'found_location': '2400 Wickersham in Austin (TX)',
#   'intake_type': 'Stray',
#   'intake_condition': 'Normal',
#   'animal_type': 'Dog',
#   'sex_upon_intake': 'Intact Male',
#   'age_upon_intake': '8 years',
#   'breed': 'Rat Terrier Mix',
#   'color': 'Tricolor'},
#  {'animal_id': 'A665426',
#   'name': 'Silka',
#   'datetime': '2013-10-17T16:53:00.000',
#   'datetime2': '2013-10-17T16:53:00.000',
#   'found_location': '8224 Research Blvd #244 in Austin (TX)',
#   'intake_type': 'Stray',
#   'intake_condition': 'Normal',
#   'animal_type': 'Cat',
#   'sex_upon_intake': 'Intact Male',
#   'age_upon_intake': '1 month',
#   'breed': 'Domestic Shorthair Mix',
#   'color': 'Black'},
#  {'animal_id': 'A664742',
#   'name': 'Angel',
#   'datetime': '2013-10-08T15:16:00.000',
#   'datetime2': '2013-10-08T15:16:00.000',
#   'found_location': 'Walsh Tarlton in Travis (TX)',
#   'intake_type': 'Stray',
#   'intake_condition': 'Normal',
#   'animal_type': 'Dog',
#   'sex_upon_intake': 'Intact Female',
#   'age_upon_intake': '4 years',
#   'breed': 'Dachshund Mix',
#   'color': 'Black/White'},
#  {'animal_id': 'A665304',
#   'name': 'Flynn',
#   'datetime': '2013-10-16T11:23:00.000',
#   'datetime2': '2013-10-16T11:23:00.000',
#   'found_location': 'Orleans And Willima Cannon in Austin (TX)',
#   'intake_type': 'Stray',
#   'intake_condition': 'Normal',
#   'animal_type': 'Dog',
#   'sex_upon_intake': 'Intact Male',
#   'age_upon_intake': '1 month',
#   'breed': 'Newfoundland/Australian Cattle Dog',
#   'color': 'Black/White'},
#  {'animal_id': 'A665156',
#   'name': 'Baby Elic',
#   'datetime': '2013-10-14T13:45:00.000',
#   'datetime2': '2013-10-14T13:45:00.000',
#   'found_location': 'Wm Cannon And Pleasant Valley in Austin (TX)',
#   'intake_type': 'Stray',
#   'intake_condition': 'Normal',
#   'animal_type': 'Dog',
#   'sex_upon_intake': 'Intact Female',
#   'age_upon_intake': '9 months',
#   'breed': 'Border Collie Mix',
#   'color': 'White/Black'},
#  {'animal_id': 'A665303',
#   'datetime': '2013-10-16T11:19:00.000',
#   'datetime2': '2013-10-16T11:19:00.000',
#   'found_location': '614 S 1St St in Austin (TX)',
#   'intake_type': 'Stray',
#   'intake_condition': 'Normal',
#   'animal_type': 'Cat',
#   'sex_upon_intake': 'Neutered Male',
#   'age_upon_intake': '6 years',
#   'breed': 'Domestic Medium Hair Mix',
#   'color': 'Black/White'},
#  {'animal_id': 'A664237',
#   'datetime': '2013-10-01T08:33:00.000',
#   'datetime2': '2013-10-01T08:33:00.000',
#   'found_location': 'Abia in Austin (TX)',
#   'intake_type': 'Stray',
#   'intake_condition': 'Normal',
#   'animal_type': 'Cat',
#   'sex_upon_intake': 'Unknown',
#   'age_upon_intake': '1 week',
#   'breed': 'Domestic Shorthair Mix',
#   'color': 'Orange/White'},
#  {'animal_id': 'A665209',
#   'name': '*Tilly',
#   'datetime': '2013-10-15T11:44:00.000',
#   'datetime2': '2013-10-15T11:44:00.000',
#   'found_location': '2000 Centimeter Dr in Austin (TX)',
#   'intake_type': 'Stray',
#   'intake_condition': 'Injured',
#   'animal_type': 'Cat',
#   'sex_upon_intake': 'Intact Female',
#   'age_upon_intake': '6 years',
#   'breed': 'Domestic Shorthair Mix',
#   'color': 'Brown Tabby'},
#  {'animal_id': 'A656761',
#   'name': 'Gotti',
#   'datetime': '2013-10-02T15:02:00.000',
#   'datetime2': '2013-10-02T15:02:00.000',
#   'found_location': 'Austin (TX)',
#   'intake_type': 'Public Assist',
#   'intake_condition': 'Normal',
#   'animal_type': 'Dog',
#   'sex_upon_intake': 'Intact Male',
#   'age_upon_intake': '7 years',
#   'breed': 'Pit Bull Mix',
#   'color': 'Fawn'},
#  {'animal_id': 'A665150',
#   'datetime': '2013-10-14T12:40:00.000',
#   'datetime2': '2013-10-14T12:40:00.000',
#   'found_location': '8704 Ingrid Dr in Travis (TX)',
#   'intake_type': 'Stray',
#   'intake_condition': 'Normal',
#   'animal_type': 'Dog',
#   'sex_upon_intake': 'Intact Male',
#   'age_upon_intake': '4 weeks',
#   'breed': 'Chihuahua Shorthair Mix',
#   'color': 'Sable'},
#  {'animal_id': 'A664439',
#   'name': 'Batty',
#   'datetime': '2013-10-03T12:38:00.000',
#   'datetime2': '2013-10-03T12:38:00.000',
#   'found_location': 'Airport/46Th St in Austin (TX)',
#   'intake_type': 'Stray',
#   'intake_condition': 'Normal',
#   'animal_type': 'Dog',
#   'sex_upon_intake': 'Intact Male',
#   'age_upon_intake': '4 months',
#   'breed': 'Dachshund/Rat Terrier',
#   'color': 'White/Black'},
#  {'animal_id': 'A666093',
#   'name': 'Kirby',
#   'datetime': '2013-10-26T17:42:00.000',
#   'datetime2': '2013-10-26T17:42:00.000',
#   'found_location': 'Dg Collins in Austin (TX)',
#   'intake_type': 'Stray',
#   'intake_condition': 'Normal',
#   'animal_type': 'Dog',
#   'sex_upon_intake': 'Neutered Male',
#   'age_upon_intake': '3 years',
#   'breed': 'Labrador Retriever Mix',
#   'color': 'Black'},
#  {'animal_id': 'A665568',
#   'datetime': '2013-10-19T13:44:00.000',
#   'datetime2': '2013-10-19T13:44:00.000',
#   'found_location': '2712  Zaragosa St in Austin (TX)',
#   'intake_type': 'Stray',
#   'intake_condition': 'Normal',
#   'animal_type': 'Dog',
#   'sex_upon_intake': 'Intact Male',
#   'age_upon_intake': '2 months',
#   'breed': 'Chihuahua Shorthair',
#   'color': 'Black'},
#  {'animal_id': 'A664490',
#   'name': '*Nikko',
#   'datetime': '2013-10-04T11:05:00.000',
#   'datetime2': '2013-10-04T11:05:00.000',
#   'found_location': '6001 Cougar Dr in Austin (TX)',
#   'intake_type': 'Stray',
#   'intake_condition': 'Normal',
#   'animal_type': 'Dog',
#   'sex_upon_intake': 'Intact Male',
#   'age_upon_intake': '1 month',
#   'breed': 'Labrador Retriever Mix',
#   'color': 'Black'},
#  {'animal_id': 'A665224',
#   'name': 'Jet',
#   'datetime': '2013-10-15T12:33:00.000',
#   'datetime2': '2013-10-15T12:33:00.000',
#   'found_location': 'Austin (TX)',
#   'intake_type': 'Owner Surrender',
#   'intake_condition': 'Normal',
#   'animal_type': 'Dog',
#   'sex_upon_intake': 'Intact Male',
#   'age_upon_intake': '1 year',
#   'breed': 'Flat Coat Retriever Mix',
#   'color': 'Black/White'},
#  {'animal_id': 'A651630',
#   'name': 'Heather',
#   'datetime': '2013-10-01T11:23:00.000',
#   'datetime2': '2013-10-01T11:23:00.000',
#   'found_location': 'Outside Jurisdiction',
#   'intake_type': 'Owner Surrender',
#   'intake_condition': 'Injured',
#   'animal_type': 'Dog',
#   'sex_upon_intake': 'Spayed Female',
#   'age_upon_intake': '6 years',
#   'breed': 'Labrador Retriever/Chinese Sharpei',
#   'color': 'Tan'},
#  {'animal_id': 'A666091',
#   'name': 'Willy',
#   'datetime': '2013-10-26T16:43:00.000',
#   'datetime2': '2013-10-26T16:43:00.000',
#   'found_location': '5300 Pecan Brook in Austin (TX)',
#   'intake_type': 'Stray',
#   'intake_condition': 'Normal',
#   'animal_type': 'Cat',
#   'sex_upon_intake': 'Intact Male',
#   'age_upon_intake': '1 month',
#   'breed': 'Domestic Medium Hair Mix',
#   'color': 'Black/White'},
#  {'animal_id': 'A665874',
#   'name': 'Tripp',
#   'datetime': '2013-10-24T07:48:00.000',
#   'datetime2': '2013-10-24T07:48:00.000',
#   'found_location': '4434 Frontier Trl in Austin (TX)',
#   'intake_type': 'Stray',
#   'intake_condition': 'Normal',
#   'animal_type': 'Dog',
#   'sex_upon_intake': 'Neutered Male',
#   'age_upon_intake': '9 months',
#   'breed': 'Pit Bull Mix',
#   'color': 'Brown/White'},
#  {'animal_id': 'A664563',
#   'name': 'Lola',
#   'datetime': '2013-10-05T13:21:00.000',
#   'datetime2': '2013-10-05T13:21:00.000',
#   'found_location': '2815 E 71 in Austin (TX)',
#   'intake_type': 'Stray',
#   'intake_condition': 'Normal',
#   'animal_type': 'Dog',
#   'sex_upon_intake': 'Spayed Female',
#   'age_upon_intake': '3 years',
#   'breed': 'Pit Bull Mix',
#   'color': 'Tan'},
#  {'animal_id': 'A594707',
#   'name': '*Frisco',
#   'datetime': '2013-10-02T12:36:00.000',
#   'datetime2': '2013-10-02T12:36:00.000',
#   'found_location': 'Austin (TX)',
#   'intake_type': 'Public Assist',
#   'intake_condition': 'Normal',
#   'animal_type': 'Dog',
#   'sex_upon_intake': 'Spayed Female',
#   'age_upon_intake': '4 years',
#   'breed': 'German Shepherd/Labrador Retriever',
#   'color': 'White'},
#  {'animal_id': 'A664837',
#   'datetime': '2013-10-09T17:48:00.000',
#   'datetime2': '2013-10-09T17:48:00.000',
#   'found_location': '901 W 9Th St in Austin (TX)',
#   'intake_type': 'Stray',
#   'intake_condition': 'Normal',
#   'animal_type': 'Cat',
#   'sex_upon_intake': 'Intact Male',
#   'age_upon_intake': '2 weeks',
#   'breed': 'Domestic Shorthair Mix',
#   'color': 'Black'},
#  {'animal_id': 'A665211',
#   'name': '*Rasmussen',
#   'datetime': '2013-10-15T12:02:00.000',
#   'datetime2': '2013-10-15T12:02:00.000',
#   'found_location': '8800 Milton Lease Dr in Austin (TX)',
#   'intake_type': 'Stray',
#   'intake_condition': 'Normal',
#   'animal_type': 'Dog',
#   'sex_upon_intake': 'Intact Male',
#   'age_upon_intake': '3 years',
#   'breed': 'Chow Chow Mix',
#   'color': 'Red/Black'},
#  {'animal_id': 'A664540',
#   'name': 'Baby Girl',
#   'datetime': '2013-10-05T11:15:00.000',
#   'datetime2': '2013-10-05T11:15:00.000',
#   'found_location': '2600 Mallard Green Cove in Austin (TX)',
#   'intake_type': 'Stray',
#   'intake_condition': 'Normal',
#   'animal_type': 'Dog',
#   'sex_upon_intake': 'Intact Female',
#   'age_upon_intake': '1 year',
#   'breed': 'Rat Terrier Mix',
#   'color': 'Tricolor'},
#  {'animal_id': 'A549167',
#   'name': 'Manda',
#   'datetime': '2013-10-05T13:56:00.000',
#   'datetime2': '2013-10-05T13:56:00.000',
#   'found_location': 'Williamson (TX)',
#   'intake_type': 'Owner Surrender',
#   'intake_condition': 'Normal',
#   'animal_type': 'Dog',
#   'sex_upon_intake': 'Spayed Female',
#   'age_upon_intake': '5 years',
#   'breed': 'Great Pyrenees/Border Collie',
#   'color': 'White/Black'},
#  {'animal_id': 'A665188',
#   'datetime': '2013-10-14T22:25:00.000',
#   'datetime2': '2013-10-14T22:25:00.000',
#   'found_location': '2207 Pasadena Dr in Austin (TX)',
#   'intake_type': 'Wildlife',
#   'intake_condition': 'Normal',
#   'animal_type': 'Other',
#   'sex_upon_intake': 'Unknown',
#   'age_upon_intake': '4 weeks',
#   'breed': 'Bat',
#   'color': 'Brown/Black'},
#  {'animal_id': 'A664273',
#   'name': 'Buffy',
#   'datetime': '2013-10-01T13:32:00.000',
#   'datetime2': '2013-10-01T13:32:00.000',
#   'found_location': 'Berkman Dr & Briarcliff Blvd in Austin (TX)',
#   'intake_type': 'Stray',
#   'intake_condition': 'Normal',
#   'animal_type': 'Dog',
#   'sex_upon_intake': 'Intact Female',
#   'age_upon_intake': '1 year',
#   'breed': 'Dachshund/Chihuahua Shorthair',
#   'color': 'Brown'},
#  {'animal_id': 'A665201',
#   'datetime': '2013-10-15T11:09:00.000',
#   'datetime2': '2013-10-15T11:09:00.000',
#   'found_location': '2206 Riverside Farms Rd in Austin (TX)',
#   'intake_type': 'Stray',
#   'intake_condition': 'Normal',
#   'animal_type': 'Cat',
#   'sex_upon_intake': 'Intact Male',
#   'age_upon_intake': '6 months',
#   'breed': 'Domestic Shorthair Mix',
#   'color': 'Orange Tabby/White'},
#  {'animal_id': 'A664234',
#   'datetime': '2013-10-01T10:37:00.000',
#   'datetime2': '2013-10-01T10:37:00.000',
#   'found_location': '5400 Jimmy Clay in Austin (TX)',
#   'intake_type': 'Stray',
#   'intake_condition': 'Injured',
#   'animal_type': 'Dog',
#   'sex_upon_intake': 'Intact Male',
#   'age_upon_intake': '8 years',
#   'breed': 'Border Collie Mix',
#   'color': 'Black/White'},
#  {'animal_id': 'A664487',
#   'name': '*Chris Angel',
#   'datetime': '2013-10-04T11:01:00.000',
#   'datetime2': '2013-10-04T11:01:00.000',
#   'found_location': '9209 Quail Cv in Austin (TX)',
#   'intake_type': 'Stray',
#   'intake_condition': 'Normal',
#   'animal_type': 'Cat',
#   'sex_upon_intake': 'Intact Male',
#   'age_upon_intake': '1 month',
#   'breed': 'Domestic Shorthair Mix',
#   'color': 'Orange Tabby'},
#  {'animal_id': 'A664258',
#   'name': 'Sylvio',
#   'datetime': '2013-10-01T11:15:00.000',
#   'datetime2': '2013-10-01T11:15:00.000',
#   'found_location': 'Fm 1626/Manchaca Rd in Travis (TX)',
#   'intake_type': 'Stray',
#   'intake_condition': 'Normal',
#   'animal_type': 'Dog',
#   'sex_upon_intake': 'Neutered Male',
#   'age_upon_intake': '7 years',
#   'breed': 'Weimaraner Mix',
#   'color': 'Silver'},
#  {'animal_id': 'A665680',
#   'datetime': '2013-10-21T15:42:00.000',
#   'datetime2': '2013-10-21T15:42:00.000',
#   'found_location': 'Pine Arbor Trl in Manor (TX)',
#   'intake_type': 'Stray',
#   'intake_condition': 'Normal',
#   'animal_type': 'Dog',
#   'sex_upon_intake': 'Intact Female',
#   'age_upon_intake': '5 months',
#   'breed': 'Chihuahua Shorthair Mix',
#   'color': 'Buff'},
#  {'animal_id': 'A664579',
#   'datetime': '2013-10-05T14:55:00.000',
#   'datetime2': '2013-10-05T14:55:00.000',
#   'found_location': '8425 Adirondack Trail in Austin (TX)',
#   'intake_type': 'Wildlife',
#   'intake_condition': 'Sick',
#   'animal_type': 'Other',
#   'sex_upon_intake': 'Unknown',
#   'age_upon_intake': '2 years',
#   'breed': 'Raccoon Mix',
#   'color': 'Black/White'},
#  {'animal_id': 'A664353',
#   'name': 'Ziggy',
#   'datetime': '2013-10-02T13:22:00.000',
#   'datetime2': '2013-10-02T13:22:00.000',
#   'found_location': '7218 Lakecharles Dr in Austin (TX)',
#   'intake_type': 'Stray',
#   'intake_condition': 'Normal',
#   'animal_type': 'Dog',
#   'sex_upon_intake': 'Intact Male',
#   'age_upon_intake': '2 years',
#   'breed': 'German Shepherd/Alaskan Husky',
#   'color': 'White'},
#  {'animal_id': 'A665220',
#   'datetime': '2013-10-15T12:23:00.000',
#   'datetime2': '2013-10-15T12:23:00.000',
#   'found_location': '4404 Imperial in Travis (TX)',
#   'intake_type': 'Stray',
#   'intake_condition': 'Normal',
#   'animal_type': 'Dog',
#   'sex_upon_intake': 'Intact Male',
#   'age_upon_intake': '1 month',
#   'breed': 'Australian Cattle Dog Mix',
#   'color': 'Tricolor'},
#  {'animal_id': 'A664517',
#   'name': 'Cheddar',
#   'datetime': '2013-10-04T15:23:00.000',
#   'datetime2': '2013-10-04T15:23:00.000',
#   'found_location': '14100 Thermal Dr in Austin (TX)',
#   'intake_type': 'Owner Surrender',
#   'intake_condition': 'Normal',
#   'animal_type': 'Cat',
#   'sex_upon_intake': 'Intact Male',
#   'age_upon_intake': '3 months',
#   'breed': 'Domestic Shorthair Mix',
#   'color': 'Cream Tabby'},
#  {'animal_id': 'A665219',
#   'name': 'Sox',
#   'datetime': '2013-10-15T12:23:00.000',
#   'datetime2': '2013-10-15T12:23:00.000',
#   'found_location': '4404 Imperial in Travis (TX)',
#   'intake_type': 'Stray',
#   'intake_condition': 'Normal',
#   'animal_type': 'Dog',
#   'sex_upon_intake': 'Intact Male',
#   'age_upon_intake': '1 month',
#   'breed': 'Australian Shepherd Mix',
#   'color': 'Tricolor'},
#  {'animal_id': 'A664702',
#   'name': 'Harley',
#   'datetime': '2013-10-08T15:30:00.000',
#   'datetime2': '2013-10-08T15:30:00.000',
#   'found_location': 'Brodie Ln/Hwy 290 in Austin (TX)',
#   'intake_type': 'Stray',
#   'intake_condition': 'Normal',
#   'animal_type': 'Dog',
#   'sex_upon_intake': 'Neutered Male',
#   'age_upon_intake': '4 years',
#   'breed': 'American Bulldog Mix',
#   'color': 'White'},
#  {'animal_id': 'A665962',
#   'name': 'Beya',
#   'datetime': '2013-10-25T11:01:00.000',
#   'datetime2': '2013-10-25T11:01:00.000',
#   'found_location': 'Austin (TX)',
#   'intake_type': 'Owner Surrender',
#   'intake_condition': 'Normal',
#   'animal_type': 'Dog',
#   'sex_upon_intake': 'Spayed Female',
#   'age_upon_intake': '9 years',
#   'breed': 'Labrador Retriever Mix',
#   'color': 'Black/White'},
#  {'animal_id': 'A665775',
#   'name': 'Hawk',
#   'datetime': '2013-10-22T16:27:00.000',
#   'datetime2': '2013-10-22T16:27:00.000',
#   'found_location': 'Austin (TX)',
#   'intake_type': 'Owner Surrender',
#   'intake_condition': 'Normal',
#   'animal_type': 'Dog',
#   'sex_upon_intake': 'Neutered Male',
#   'age_upon_intake': '8 months',
#   'breed': 'Labrador Retriever Mix',
#   'color': 'Black'},
#  {'animal_id': 'A665162',
#   'name': 'Diamond',
#   'datetime': '2013-10-14T14:48:00.000',
#   'datetime2': '2013-10-14T14:48:00.000',
#   'found_location': 'Harris Branch/Colinton Ave in Austin (TX)',
#   'intake_type': 'Stray',
#   'intake_condition': 'Normal',
#   'animal_type': 'Dog',
#   'sex_upon_intake': 'Intact Female',
#   'age_upon_intake': '4 months',
#   'breed': 'Pit Bull Mix',
#   'color': 'Blue/White'},
#  {'animal_id': 'A665994',
#   'name': '*Lihue',
#   'datetime': '2013-10-25T17:41:00.000',
#   'datetime2': '2013-10-25T17:41:00.000',
#   'found_location': 'N Ih 35 in Austin (TX)',
#   'intake_type': 'Stray',
#   'intake_condition': 'Normal',
#   'animal_type': 'Cat',
#   'sex_upon_intake': 'Intact Female',
#   'age_upon_intake': '3 months',
#   'breed': 'Domestic Shorthair Mix',
#   'color': 'Calico'},
#  {'animal_id': 'A665657',
#   'datetime': '2013-10-21T12:20:00.000',
#   'datetime2': '2013-10-21T12:20:00.000',
#   'found_location': '2900 Sunridge Dr in Austin (TX)',
#   'intake_type': 'Stray',
#   'intake_condition': 'Normal',
#   'animal_type': 'Cat',
#   'sex_upon_intake': 'Intact Male',
#   'age_upon_intake': '1 month',
#   'breed': 'Domestic Shorthair Mix',
#   'color': 'Brown Tabby'},
#  {'animal_id': 'A651690',
#   'name': 'Rocky',
#   'datetime': '2013-10-04T17:36:00.000',
#   'datetime2': '2013-10-04T17:36:00.000',
#   'found_location': 'Grove/ Fairway in Austin (TX)',
#   'intake_type': 'Stray',
#   'intake_condition': 'Normal',
#   'animal_type': 'Dog',
#   'sex_upon_intake': 'Neutered Male',
#   'age_upon_intake': '2 years',
#   'breed': 'Chihuahua Shorthair Mix',
#   'color': 'Brown'},
#  {'animal_id': 'A664893',
#   'name': '*Midge',
#   'datetime': '2013-10-10T15:02:00.000',
#   'datetime2': '2013-10-10T15:02:00.000',
#   'found_location': 'Muffin Dr in Austin (TX)',
#   'intake_type': 'Stray',
#   'intake_condition': 'Normal',
#   'animal_type': 'Dog',
#   'sex_upon_intake': 'Intact Female',
#   'age_upon_intake': '1 month',
#   'breed': 'Black Mouth Cur/Dachshund',
#   'color': 'Tan/White'},
#  {'animal_id': 'A665159',
#   'name': 'Skipper',
#   'datetime': '2013-10-14T14:38:00.000',
#   'datetime2': '2013-10-14T14:38:00.000',
#   'found_location': '4Th St And Navasota in Austin (TX)',
#   'intake_type': 'Stray',
#   'intake_condition': 'Normal',
#   'animal_type': 'Dog',
#   'sex_upon_intake': 'Intact Male',
#   'age_upon_intake': '3 years',
#   'breed': 'German Shepherd Mix',
#   'color': 'Sable'},
#  {'animal_id': 'A663055',
#   'name': 'Mocha',
#   'datetime': '2013-10-23T17:06:00.000',
#   'datetime2': '2013-10-23T17:06:00.000',
#   'found_location': 'Austin (TX)',
#   'intake_type': 'Owner Surrender',
#   'intake_condition': 'Normal',
#   'animal_type': 'Dog',
#   'sex_upon_intake': 'Spayed Female',
#   'age_upon_intake': '1 year',
#   'breed': 'Pit Bull Mix',
#   'color': 'Brown/White'},
#  {'animal_id': 'A529609',
#   'name': 'Billy Jean',
#   'datetime': '2013-10-13T16:01:00.000',
#   'datetime2': '2013-10-13T16:01:00.000',
#   'found_location': '3200 Duval in Austin (TX)',
#   'intake_type': 'Stray',
#   'intake_condition': 'Normal',
#   'animal_type': 'Dog',
#   'sex_upon_intake': 'Spayed Female',
#   'age_upon_intake': '5 years',
#   'breed': 'Belgian Malinois/Australian Shepherd',
#   'color': 'Brown/Brown Merle'},
#  {'animal_id': 'A666074',
#   'name': '*Jackson',
#   'datetime': '2013-10-26T14:45:00.000',
#   'datetime2': '2013-10-26T14:45:00.000',
#   'found_location': '5240 Mathra in Del Valle (TX)',
#   'intake_type': 'Stray',
#   'intake_condition': 'Normal',
#   'animal_type': 'Cat',
#   'sex_upon_intake': 'Intact Male',
#   'age_upon_intake': '4 weeks',
#   'breed': 'Domestic Shorthair Mix',
#   'color': 'Brown Tabby'},
#  {'animal_id': 'A664342',
#   'name': '*Miso',
#   'datetime': '2013-10-02T12:10:00.000',
#   'datetime2': '2013-10-02T12:10:00.000',
#   'found_location': 'Carnation in Austin (TX)',
#   'intake_type': 'Stray',
#   'intake_condition': 'Injured',
#   'animal_type': 'Dog',
#   'sex_upon_intake': 'Intact Female',
#   'age_upon_intake': '1 year',
#   'breed': 'Japanese Chin Mix',
#   'color': 'White/Black'},
#  {'animal_id': 'A664504',
#   'name': 'Matilda',
#   'datetime': '2013-10-04T12:22:00.000',
#   'datetime2': '2013-10-04T12:22:00.000',
#   'found_location': 'Austin (TX)',
#   'intake_type': 'Stray',
#   'intake_condition': 'Normal',
#   'animal_type': 'Dog',
#   'sex_upon_intake': 'Spayed Female',
#   'age_upon_intake': '6 months',
#   'breed': 'Pit Bull Mix',
#   'color': 'White/Blue'},
#  {'animal_id': 'A664597',
#   'name': 'Phoebe',
#   'datetime': '2013-10-05T16:17:00.000',
#   'datetime2': '2013-10-05T16:17:00.000',
#   'found_location': '183/Fm 812 in Austin (TX)',
#   'intake_type': 'Stray',
#   'intake_condition': 'Other',
#   'animal_type': 'Dog',
#   'sex_upon_intake': 'Intact Female',
#   'age_upon_intake': '4 months',
#   'breed': 'Pit Bull Mix',
#   'color': 'Blue/White'},
#  {'animal_id': 'A664572',
#   'name': 'Twilight',
#   'datetime': '2013-10-05T14:10:00.000',
#   'datetime2': '2013-10-05T14:10:00.000',
#   'found_location': 'Hwy 183 And  51St  St in Austin (TX)',
#   'intake_type': 'Stray',
#   'intake_condition': 'Normal',
#   'animal_type': 'Dog',
#   'sex_upon_intake': 'Spayed Female',
#   'age_upon_intake': '2 years',
#   'breed': 'Chihuahua Shorthair Mix',
#   'color': 'White/Brown'},
#  {'animal_id': 'A665395',
#   'name': '*Hawkeye',
#   'datetime': '2013-10-17T12:26:00.000',
#   'datetime2': '2013-10-17T12:26:00.000',
#   'found_location': 'Austin (TX)',
#   'intake_type': 'Owner Surrender',
#   'intake_condition': 'Normal',
#   'animal_type': 'Cat',
#   'sex_upon_intake': 'Intact Male',
#   'age_upon_intake': '6 months',
#   'breed': 'Domestic Shorthair Mix',
#   'color': 'White/Black'},
#  {'animal_id': 'A664662',
#   'name': 'Scout',
#   'datetime': '2013-10-07T11:05:00.000',
#   'datetime2': '2013-10-07T11:05:00.000',
#   'found_location': 'Ray  And Means in Austin (TX)',
#   'intake_type': 'Stray',
#   'intake_condition': 'Normal',
#   'animal_type': 'Dog',
#   'sex_upon_intake': 'Intact Female',
#   'age_upon_intake': '1 month',
#   'breed': 'Treeing Walker Coonhound Mix',
#   'color': 'White/Black'},
#  {'animal_id': 'A666004',
#   'name': 'Suki',
#   'datetime': '2013-10-25T18:59:00.000',
#   'datetime2': '2013-10-25T18:59:00.000',
#   'found_location': 'Chicon/E 2Nd in Austin (TX)',
#   'intake_type': 'Stray',
#   'intake_condition': 'Normal',
#   'animal_type': 'Dog',
#   'sex_upon_intake': 'Intact Female',
#   'age_upon_intake': '4 years',
#   'breed': 'Miniature Schnauzer/Miniature Poodle',
#   'color': 'Sable/Tan'},
#  {'animal_id': 'A664778',
#   'name': 'Brutus',
#   'datetime': '2013-10-08T18:35:00.000',
#   'datetime2': '2013-10-08T18:35:00.000',
#   'found_location': 'Austin (TX)',
#   'intake_type': 'Public Assist',
#   'intake_condition': 'Normal',
#   'animal_type': 'Dog',
#   'sex_upon_intake': 'Neutered Male',
#   'age_upon_intake': '4 years',
#   'breed': 'Pit Bull/Boxer',
#   'color': 'Brown/White'},
#  {'animal_id': 'A665547',
#   'datetime': '2013-10-19T11:02:00.000',
#   'datetime2': '2013-10-19T11:02:00.000',
#   'found_location': '6707 Colony Park Cove in Austin (TX)',
#   'intake_type': 'Stray',
#   'intake_condition': 'Normal',
#   'animal_type': 'Dog',
#   'sex_upon_intake': 'Intact Male',
#   'age_upon_intake': '1 month',
#   'breed': 'Chinese Sharpei Mix',
#   'color': 'Cream'},
#  {'animal_id': 'A665691',
#   'name': 'Zoey',
#   'datetime': '2013-10-21T16:41:00.000',
#   'datetime2': '2013-10-21T16:41:00.000',
#   'found_location': '10005 Derringer Trl in Austin (TX)',
#   'intake_type': 'Stray',
#   'intake_condition': 'Normal',
#   'animal_type': 'Dog',
#   'sex_upon_intake': 'Intact Female',
#   'age_upon_intake': '2 years',
#   'breed': 'Chihuahua Shorthair Mix',
#   'color': 'Buff'},
#  {'animal_id': 'A665939',
#   'name': '*Pat',
#   'datetime': '2013-10-24T16:05:00.000',
#   'datetime2': '2013-10-24T16:05:00.000',
#   'found_location': '1704 Nelms Dr in Austin (TX)',
#   'intake_type': 'Stray',
#   'intake_condition': 'Normal',
#   'animal_type': 'Cat',
#   'sex_upon_intake': 'Intact Female',
#   'age_upon_intake': '1 year',
#   'breed': 'Domestic Medium Hair Mix',
#   'color': 'Black'},
#  {'animal_id': 'A652564',
#   'name': 'G-Unit',
#   'datetime': '2013-10-22T14:23:00.000',
#   'datetime2': '2013-10-22T14:23:00.000',
#   'found_location': '1106 Jolena in Austin (TX)',
#   'intake_type': 'Stray',
#   'intake_condition': 'Normal',
#   'animal_type': 'Dog',
#   'sex_upon_intake': 'Neutered Male',
#   'age_upon_intake': '4 years',
#   'breed': 'Pit Bull Mix',
#   'color': 'Brown Brindle'},
#  {'animal_id': 'A666016',
#   'datetime': '2013-10-26T08:02:00.000',
#   'datetime2': '2013-10-26T08:02:00.000',
#   'found_location': '4434 Frontier Trl in Austin (TX)',
#   'intake_type': 'Stray',
#   'intake_condition': 'Nursing',
#   'animal_type': 'Cat',
#   'sex_upon_intake': 'Unknown',
#   'age_upon_intake': '4 weeks',
#   'breed': 'Domestic Longhair Mix',
#   'color': 'Blue Tabby/White'},
#  {'animal_id': 'A665948',
#   'datetime': '2013-10-24T16:50:00.000',
#   'datetime2': '2013-10-24T16:50:00.000',
#   'found_location': '7Th And Pleasant Valley in Austin (TX)',
#   'intake_type': 'Stray',
#   'intake_condition': 'Normal',
#   'animal_type': 'Dog',
#   'sex_upon_intake': 'Intact Male',
#   'age_upon_intake': '4 months',
#   'breed': 'American Bulldog Mix',
#   'color': 'Brown Brindle/White'},
#  {'animal_id': 'A609552',
#   'name': 'Zuzu',
#   'datetime': '2013-10-02T07:41:00.000',
#   'datetime2': '2013-10-02T07:41:00.000',
#   'found_location': '4434 Frontier in Austin (TX)',
#   'intake_type': 'Stray',
#   'intake_condition': 'Normal',
#   'animal_type': 'Dog',
#   'sex_upon_intake': 'Spayed Female',
#   'age_upon_intake': '2 years',
#   'breed': 'Doberman Pinsch/Pit Bull',
#   'color': 'Black/Tan'},
#  {'animal_id': 'A654375',
#   'name': 'Pixie',
#   'datetime': '2013-10-20T16:55:00.000',
#   'datetime2': '2013-10-20T16:55:00.000',
#   'found_location': 'Pflugerville (TX)',
#   'intake_type': 'Owner Surrender',
#   'intake_condition': 'Normal',
#   'animal_type': 'Dog',
#   'sex_upon_intake': 'Spayed Female',
#   'age_upon_intake': '5 months',
#   'breed': 'Pit Bull Mix',
#   'color': 'Chocolate/White'},
#  {'animal_id': 'A664259',
#   'name': '*Petunia',
#   'datetime': '2013-10-01T11:25:00.000',
#   'datetime2': '2013-10-01T11:25:00.000',
#   'found_location': '5001 Creek Bend in Austin (TX)',
#   'intake_type': 'Stray',
#   'intake_condition': 'Normal',
#   'animal_type': 'Dog',
#   'sex_upon_intake': 'Intact Female',
#   'age_upon_intake': '5 years',
#   'breed': 'Pit Bull Mix',
#   'color': 'Black'},
#  {'animal_id': 'A665620',
#   'name': 'Mona',
#   'datetime': '2013-10-20T12:30:00.000',
#   'datetime2': '2013-10-20T12:30:00.000',
#   'found_location': '14508 Harris Ridge Blvd in Austin (TX)',
#   'intake_type': 'Stray',
#   'intake_condition': 'Normal',
#   'animal_type': 'Dog',
#   'sex_upon_intake': 'Intact Female',
#   'age_upon_intake': '11 months',
#   'breed': 'Chihuahua Shorthair Mix',
#   'color': 'Tricolor'},
#  {'animal_id': 'A658735',
#   'name': 'Ruby',
#   'datetime': '2013-10-12T15:10:00.000',
#   'datetime2': '2013-10-12T15:10:00.000',
#   'found_location': '6800 North Lamar in Austin (TX)',
#   'intake_type': 'Stray',
#   'intake_condition': 'Normal',
#   'animal_type': 'Dog',
#   'sex_upon_intake': 'Spayed Female',
#   'age_upon_intake': '1 year',
#   'breed': 'Dachshund/Cardigan Welsh Corgi',
#   'color': 'Red/White'},
#  {'animal_id': 'A664387',
#   'datetime': '2013-10-02T18:20:00.000',
#   'datetime2': '2013-10-02T18:20:00.000',
#   'found_location': '5002 Blue Spruce in Austin (TX)',
#   'intake_type': 'Stray',
#   'intake_condition': 'Normal',
#   'animal_type': 'Cat',
#   'sex_upon_intake': 'Intact Female',
#   'age_upon_intake': '2 weeks',
#   'breed': 'Domestic Shorthair Mix',
#   'color': 'Blue Tabby'},
#  {'animal_id': 'A653703',
#   'name': '*Poodle',
#   'datetime': '2013-10-02T16:30:00.000',
#   'datetime2': '2013-10-02T16:30:00.000',
#   'found_location': '1515 Wickersham in Austin (TX)',
#   'intake_type': 'Stray',
#   'intake_condition': 'Normal',
#   'animal_type': 'Dog',
#   'sex_upon_intake': 'Neutered Male',
#   'age_upon_intake': '5 years',
#   'breed': 'Miniature Poodle',
#   'color': 'Tan'},
#  {'animal_id': 'A665595',
#   'name': 'Terrance',
#   'datetime': '2013-10-19T18:11:00.000',
#   'datetime2': '2013-10-19T18:11:00.000',
#   'found_location': '12916 James Madison St in Manor (TX)',
#   'intake_type': 'Stray',
#   'intake_condition': 'Normal',
#   'animal_type': 'Dog',
#   'sex_upon_intake': 'Intact Male',
#   'age_upon_intake': '6 months',
#   'breed': 'Chihuahua Shorthair',
#   'color': 'Tricolor'},
#  {'animal_id': 'A664664',
#   'name': 'Izzy',
#   'datetime': '2013-10-16T10:57:00.000',
#   'datetime2': '2013-10-16T10:57:00.000',
#   'found_location': 'Austin (TX)',
#   'intake_type': 'Owner Surrender',
#   'intake_condition': 'Normal',
#   'animal_type': 'Dog',
#   'sex_upon_intake': 'Spayed Female',
#   'age_upon_intake': '6 years',
#   'breed': 'Pug Mix',
#   'color': 'Fawn'},
#  {'animal_id': 'A664857',
#   'datetime': '2013-10-10T07:47:00.000',
#   'datetime2': '2013-10-10T07:47:00.000',
#   'found_location': 'Old Bee Caves And Hwy 71 in Austin (TX)',
#   'intake_type': 'Stray',
#   'intake_condition': 'Normal',
#   'animal_type': 'Cat',
#   'sex_upon_intake': 'Intact Male',
#   'age_upon_intake': '6 months',
#   'breed': 'Domestic Shorthair Mix',
#   'color': 'Black/White'},
#  {'animal_id': 'A665926',
#   'name': '*Mike',
#   'datetime': '2013-10-24T15:18:00.000',
#   'datetime2': '2013-10-24T15:18:00.000',
#   'found_location': 'Austin (TX)',
#   'intake_type': 'Owner Surrender',
#   'intake_condition': 'Normal',
#   'animal_type': 'Cat',
#   'sex_upon_intake': 'Intact Male',
#   'age_upon_intake': '1 month',
#   'breed': 'Domestic Shorthair Mix',
#   'color': 'Orange Tabby'},
#  {'animal_id': 'A664754',
#   'datetime': '2013-10-08T16:46:00.000',
#   'datetime2': '2013-10-08T16:46:00.000',
#   'found_location': 'Austin (TX)',
#   'intake_type': 'Owner Surrender',
#   'intake_condition': 'Normal',
#   'animal_type': 'Cat',
#   'sex_upon_intake': 'Intact Male',
#   'age_upon_intake': '5 months',
#   'breed': 'Domestic Shorthair Mix',
#   'color': 'Black'},
#  {'animal_id': 'A665744',
#   'name': 'Lulu',
#   'datetime': '2013-10-22T11:42:00.000',
#   'datetime2': '2013-10-22T11:42:00.000',
#   'found_location': 'E 7Th St And Pleasant Valley in Austin (TX)',
#   'intake_type': 'Stray',
#   'intake_condition': 'Normal',
#   'animal_type': 'Dog',
#   'sex_upon_intake': 'Intact Female',
#   'age_upon_intake': '2 months',
#   'breed': 'Boxer Mix',
#   'color': 'Fawn/White'},
#  {'animal_id': 'A625774',
#   'name': 'Jumper',
#   'datetime': '2013-10-03T14:10:00.000',
#   'datetime2': '2013-10-03T14:10:00.000',
#   'found_location': '10211 Fm 969 Rd in Travis (TX)',
#   'intake_type': 'Stray',
#   'intake_condition': 'Injured',
#   'animal_type': 'Dog',
#   'sex_upon_intake': 'Neutered Male',
#   'age_upon_intake': '3 years',
#   'breed': 'Labrador Retriever Mix',
#   'color': 'Yellow'},
#  {'animal_id': 'A664446',
#   'name': '*Riley',
#   'datetime': '2013-10-03T13:06:00.000',
#   'datetime2': '2013-10-03T13:06:00.000',
#   'found_location': '6201 E 290 in Austin (TX)',
#   'intake_type': 'Stray',
#   'intake_condition': 'Injured',
#   'animal_type': 'Cat',
#   'sex_upon_intake': 'Intact Male',
#   'age_upon_intake': '3 years',
#   'breed': 'Domestic Shorthair Mix',
#   'color': 'Orange Tabby'},
#  {'animal_id': 'A664548',
#   'name': 'Katniss',
#   'datetime': '2013-10-05T11:37:00.000',
#   'datetime2': '2013-10-05T11:37:00.000',
#   'found_location': 'Austin (TX)',
#   'intake_type': 'Owner Surrender',
#   'intake_condition': 'Normal',
#   'animal_type': 'Cat',
#   'sex_upon_intake': 'Intact Female',
#   'age_upon_intake': '6 months',
#   'breed': 'Domestic Medium Hair Mix',
#   'color': 'Tortie'},
#  {'animal_id': 'A664932',
#   'datetime': '2013-10-11T10:57:00.000',
#   'datetime2': '2013-10-11T10:57:00.000',
#   'found_location': '111 Old Bastrop Hwy in Austin (TX)',
#   'intake_type': 'Stray',
#   'intake_condition': 'Normal',
#   'animal_type': 'Dog',
#   'sex_upon_intake': 'Intact Female',
#   'age_upon_intake': '2 years',
#   'breed': 'Chihuahua Longhair Mix',
#   'color': 'White/Brown'},
#  {'animal_id': 'A665315',
#   'datetime': '2013-10-16T12:46:00.000',
#   'datetime2': '2013-10-16T12:46:00.000',
#   'found_location': 'Travis (TX)',
#   'intake_type': 'Stray',
#   'intake_condition': 'Normal',
#   'animal_type': 'Dog',
#   'sex_upon_intake': 'Intact Female',
#   'age_upon_intake': '1 year',
#   'breed': 'Dachshund/Parson Russell Terrier',
#   'color': 'White/Blue Merle'},
#  {'animal_id': 'A665474',
#   'name': '*Molly',
#   'datetime': '2013-10-18T13:19:00.000',
#   'datetime2': '2013-10-18T13:19:00.000',
#   'found_location': 'Montopolis/ E Riverside in Austin (TX)',
#   'intake_type': 'Stray',
#   'intake_condition': 'Normal',
#   'animal_type': 'Cat',
#   'sex_upon_intake': 'Intact Female',
#   'age_upon_intake': '1 month',
#   'breed': 'Domestic Shorthair Mix',
#   'color': 'Black'},
#  {'animal_id': 'A665246',
#   'name': 'Alex',
#   'datetime': '2013-10-15T15:56:00.000',
#   'datetime2': '2013-10-15T15:56:00.000',
#   'found_location': '6201 Sneed Cove in Austin (TX)',
#   'intake_type': 'Stray',
#   'intake_condition': 'Normal',
#   'animal_type': 'Cat',
#   'sex_upon_intake': 'Intact Male',
#   'age_upon_intake': '1 month',
#   'breed': 'Domestic Shorthair Mix',
#   'color': 'Orange Tabby'},
#  {'animal_id': 'A612598',
#   'name': 'Harvey',
#   'datetime': '2013-10-10T14:18:00.000',
#   'datetime2': '2013-10-10T14:18:00.000',
#   'found_location': 'Austin (TX)',
#   'intake_type': 'Owner Surrender',
#   'intake_condition': 'Normal',
#   'animal_type': 'Dog',
#   'sex_upon_intake': 'Neutered Male',
#   'age_upon_intake': '3 years',
#   'breed': 'Labrador Retriever Mix',
#   'color': 'Tan/White'},
#  {'animal_id': 'A422526',
#   'name': 'Randee',
#   'datetime': '2013-10-21T11:03:00.000',
#   'datetime2': '2013-10-21T11:03:00.000',
#   'found_location': 'Austin (TX)',
#   'intake_type': 'Owner Surrender',
#   'intake_condition': 'Normal',
#   'animal_type': 'Dog',
#   'sex_upon_intake': 'Neutered Male',
#   'age_upon_intake': '13 years',
#   'breed': 'Pekingese',
#   'color': 'Yellow/Tan'},
#  {'animal_id': 'A665873',
#   'name': 'Trixie',
#   'datetime': '2013-10-26T14:12:00.000',
#   'datetime2': '2013-10-26T14:12:00.000',
#   'found_location': '11530 Manchaca in Austin (TX)',
#   'intake_type': 'Public Assist',
#   'intake_condition': 'Feral',
#   'animal_type': 'Cat',
#   'sex_upon_intake': 'Intact Female',
#   'age_upon_intake': '2 months',
#   'breed': 'Domestic Shorthair Mix',
#   'color': 'Tortie'},
#  {'animal_id': 'A664057',
#   'name': 'Oso',
#   'datetime': '2013-10-26T15:25:00.000',
#   'datetime2': '2013-10-26T15:25:00.000',
#   'found_location': 'Austin (TX)',
#   'intake_type': 'Owner Surrender',
#   'intake_condition': 'Normal',
#   'animal_type': 'Dog',
#   'sex_upon_intake': 'Intact Male',
#   'age_upon_intake': '10 months',
#   'breed': 'Pit Bull Mix',
#   'color': 'Brown/White'},
#  {'animal_id': 'A664931',
#   'name': 'Chester',
#   'datetime': '2013-10-11T10:57:00.000',
#   'datetime2': '2013-10-11T10:57:00.000',
#   'found_location': '111 Old Bastrop Hwy in Austin (TX)',
#   'intake_type': 'Stray',
#   'intake_condition': 'Normal',
#   'animal_type': 'Dog',
#   'sex_upon_intake': 'Intact Male',
#   'age_upon_intake': '1 year',
#   'breed': 'Rat Terrier Mix',
#   'color': 'White/Brown'},
#  {'animal_id': 'A665435',
#   'datetime': '2013-10-17T18:41:00.000',
#   'datetime2': '2013-10-17T18:41:00.000',
#   'found_location': '2306 Wickersham Ln in Austin (TX)',
#   'intake_type': 'Wildlife',
#   'intake_condition': 'Sick',
#   'animal_type': 'Other',
#   'sex_upon_intake': 'Unknown',
#   'age_upon_intake': '6 months',
#   'breed': 'Raccoon Mix',
#   'color': 'Brown'},
#  {'animal_id': 'A664571',
#   'datetime': '2013-10-05T13:43:00.000',
#   'datetime2': '2013-10-05T13:43:00.000',
#   'found_location': 'Austin (TX)',
#   'intake_type': 'Owner Surrender',
#   'intake_condition': 'Normal',
#   'animal_type': 'Cat',
#   'sex_upon_intake': 'Spayed Female',
#   'age_upon_intake': '2 years',
#   'breed': 'Domestic Shorthair Mix',
#   'color': 'Torbie'},
#  {'animal_id': 'A664375',
#   'name': 'Chevy',
#   'datetime': '2013-10-02T15:52:00.000',
#   'datetime2': '2013-10-02T15:52:00.000',
#   'found_location': 'Austin (TX)',
#   'intake_type': 'Public Assist',
#   'intake_condition': 'Normal',
#   'animal_type': 'Dog',
#   'sex_upon_intake': 'Intact Male',
#   'age_upon_intake': '3 years',
#   'breed': 'Labrador Retriever Mix',
#   'color': 'Black'},
#  {'animal_id': 'A664681',
#   'name': 'Pooffy',
#   'datetime': '2013-10-08T12:27:00.000',
#   'datetime2': '2013-10-08T12:27:00.000',
#   'found_location': '900 Cumberland #B in Austin (TX)',
#   'intake_type': 'Public Assist',
#   'intake_condition': 'Normal',
#   'animal_type': 'Dog',
#   'sex_upon_intake': 'Intact Female',
#   'age_upon_intake': '2 years',
#   'breed': 'Chihuahua Shorthair Mix',
#   'color': 'White/Brown'},
#  {'animal_id': 'A665414',
#   'name': 'Cactus',
#   'datetime': '2013-10-17T14:40:00.000',
#   'datetime2': '2013-10-17T14:40:00.000',
#   'found_location': '8457 Sassman in Travis (TX)',
#   'intake_type': 'Stray',
#   'intake_condition': 'Normal',
#   'animal_type': 'Dog',
#   'sex_upon_intake': 'Intact Male',
#   'age_upon_intake': '9 months',
#   'breed': 'Australian Cattle Dog/German Shepherd',
#   'color': 'Blue Merle/Brown'},
#  {'animal_id': 'A665762',
#   'datetime': '2013-10-22T15:07:00.000',
#   'datetime2': '2013-10-22T15:07:00.000',
#   'found_location': 'Travis (TX)',
#   'intake_type': 'Owner Surrender',
#   'intake_condition': 'Normal',
#   'animal_type': 'Dog',
#   'sex_upon_intake': 'Intact Male',
#   'age_upon_intake': '4 months',
#   'breed': 'Pointer Mix',
#   'color': 'Black/White'},
#  {'animal_id': 'A664363',
#   'datetime': '2013-10-02T15:01:00.000',
#   'datetime2': '2013-10-02T15:01:00.000',
#   'found_location': '20700  Fm 1431 in Lago Vista (TX)',
#   'intake_type': 'Stray',
#   'intake_condition': 'Normal',
#   'animal_type': 'Dog',
#   'sex_upon_intake': 'Intact Female',
#   'age_upon_intake': '3 years',
#   'breed': 'Labrador Retriever/German Shepherd',
#   'color': 'White'},
#  {'animal_id': 'A664309',
#   'name': '*Romo',
#   'datetime': '2013-10-01T16:19:00.000',
#   'datetime2': '2013-10-01T16:19:00.000',
#   'found_location': '12407 Emery Oaks Dr. in Austin (TX)',
#   'intake_type': 'Stray',
#   'intake_condition': 'Normal',
#   'animal_type': 'Dog',
#   'sex_upon_intake': 'Intact Male',
#   'age_upon_intake': '1 year',
#   'breed': 'Chihuahua Shorthair Mix',
#   'color': 'Tan'},
#  {'animal_id': 'A665865',
#   'name': 'Blaze',
#   'datetime': '2013-10-23T18:15:00.000',
#   'datetime2': '2013-10-23T18:15:00.000',
#   'found_location': '46Th And Red River in Austin (TX)',
#   'intake_type': 'Stray',
#   'intake_condition': 'Normal',
#   'animal_type': 'Dog',
#   'sex_upon_intake': 'Neutered Male',
#   'age_upon_intake': '3 years',
#   'breed': 'Beagle Mix',
#   'color': 'White/Tan'},
#  {'animal_id': 'A665492',
#   'name': 'Manny',
#   'datetime': '2013-10-18T17:24:00.000',
#   'datetime2': '2013-10-18T17:24:00.000',
#   'found_location': 'Austin (TX)',
#   'intake_type': 'Owner Surrender',
#   'intake_condition': 'Normal',
#   'animal_type': 'Dog',
#   'sex_upon_intake': 'Neutered Male',
#   'age_upon_intake': '1 year',
#   'breed': 'Rhod Ridgeback/Pit Bull',
#   'color': 'Red'},
#  {'animal_id': 'A666040',
#   'datetime': '2013-10-26T11:29:00.000',
#   'datetime2': '2013-10-26T11:29:00.000',
#   'found_location': '3Rd St & Comal St in Austin (TX)',
#   'intake_type': 'Stray',
#   'intake_condition': 'Normal',
#   'animal_type': 'Dog',
#   'sex_upon_intake': 'Intact Female',
#   'age_upon_intake': '4 weeks',
#   'breed': 'Rottweiler Mix',
#   'color': 'Black/Tan'},
#  {'animal_id': 'A664593',
#   'name': 'Chiquilla',
#   'datetime': '2013-10-05T16:00:00.000',
#   'datetime2': '2013-10-05T16:00:00.000',
#   'found_location': '10Th /Rio Grande in Austin (TX)',
#   'intake_type': 'Stray',
#   'intake_condition': 'Normal',
#   'animal_type': 'Dog',
#   'sex_upon_intake': 'Spayed Female',
#   'age_upon_intake': '2 years',
#   'breed': 'Chihuahua Shorthair Mix',
#   'color': 'Brown/White'},
# ...
#   'datetime': '2013-10-24T11:41:00.000',
#   'datetime2': '2013-10-24T11:41:00.000',
#   'found_location': 'Travis (TX)',
#   'intake_type': 'Owner Surrender',
#   'intake_condition': 'Normal',
#   'animal_type': 'Dog',
#   'sex_upon_intake': 'Intact Male',
#   'age_upon_intake': '2 months',
#   'breed': 'Labrador Retriever Mix',
#   'color': 'Brown'},
#  {'animal_id': 'A664723',
#   'datetime': '2013-10-08T12:10:00.000',
#   'datetime2': '2013-10-08T12:10:00.000',
#   'found_location': '9016 Yucca Mountain Rd in Austin (TX)',
#   'intake_type': 'Stray',
#   'intake_condition': 'Sick',
#   'animal_type': 'Cat',
#   'sex_upon_intake': 'Intact Female',
#   'age_upon_intake': '7 years',
#   'breed': 'Domestic Shorthair Mix',
#   'color': 'Calico'},
#  {'animal_id': 'A664958',
#   'datetime': '2013-10-11T15:21:00.000',
#   'datetime2': '2013-10-11T15:21:00.000',
#   'found_location': 'Davis/Brodie in Austin (TX)',
#   'intake_type': 'Stray',
#   'intake_condition': 'Normal',
#   'animal_type': 'Dog',
#   'sex_upon_intake': 'Intact Female',
#   'age_upon_intake': '1 month',
#   'breed': 'Labrador Retriever Mix',
#   'color': 'Black/White'},
#  {'animal_id': 'A664453',
#   'name': 'Bruno Beau',
#   'datetime': '2013-10-12T11:37:00.000',
#   'datetime2': '2013-10-12T11:37:00.000',
#   'found_location': 'Austin (TX)',
#   'intake_type': 'Owner Surrender',
#   'intake_condition': 'Normal',
#   'animal_type': 'Dog',
#   'sex_upon_intake': 'Intact Male',
#   'age_upon_intake': '1 year',
#   'breed': 'Staffordshire Mix',
#   'color': 'Brown Brindle/White'},
#  {'animal_id': 'A665429',
#   'name': '*Gilligan',
#   'datetime': '2013-10-17T17:07:00.000',
#   'datetime2': '2013-10-17T17:07:00.000',
#   'found_location': 'Austin (TX)',
#   'intake_type': 'Stray',
#   'intake_condition': 'Normal',
#   'animal_type': 'Cat',
#   'sex_upon_intake': 'Neutered Male',
#   'age_upon_intake': '2 years',
#   'breed': 'Domestic Medium Hair Mix',
#   'color': 'Black/White'},
#  {'animal_id': 'A665386',
#   'datetime': '2013-10-17T11:31:00.000',
#   'datetime2': '2013-10-17T11:31:00.000',
#   'found_location': '5200 Woodland Oaks Ct in Austin (TX)',
#   'intake_type': 'Stray',
#   'intake_condition': 'Normal',
#   'animal_type': 'Dog',
#   'sex_upon_intake': 'Intact Female',
#   'age_upon_intake': '1 year',
#   'breed': 'Chihuahua Shorthair/Rat Terrier',
#   'color': 'White/Black'},
#  {'animal_id': 'A665553',
#   'name': 'Bobbi Joe',
#   'datetime': '2013-10-19T11:42:00.000',
#   'datetime2': '2013-10-19T11:42:00.000',
#   'found_location': 'Travis (TX)',
#   'intake_type': 'Owner Surrender',
#   'intake_condition': 'Normal',
#   'animal_type': 'Cat',
#   'sex_upon_intake': 'Intact Female',
#   'age_upon_intake': '6 months',
#   'breed': 'Domestic Shorthair Mix',
#   'color': 'Brown Tabby'},
#  {'animal_id': 'A665365',
#   'name': 'Mariposa',
#   'datetime': '2013-10-16T17:39:00.000',
#   'datetime2': '2013-10-16T17:39:00.000',
#   'found_location': '5113 Park At Woodland Dr in Austin (TX)',
#   'intake_type': 'Stray',
#   'intake_condition': 'Normal',
#   'animal_type': 'Dog',
#   'sex_upon_intake': 'Spayed Female',
#   'age_upon_intake': '1 year',
#   'breed': 'Jack Russell Terrier Mix',
#   'color': 'White'},
#  {'animal_id': 'A663168',
#   'name': 'Archer',
#   'datetime': '2013-10-11T13:21:00.000',
#   'datetime2': '2013-10-11T13:21:00.000',
#   'found_location': '1010 Cesar Chavez in Austin (TX)',
#   'intake_type': 'Stray',
#   'intake_condition': 'Normal',
#   'animal_type': 'Dog',
#   'sex_upon_intake': 'Neutered Male',
#   'age_upon_intake': '1 year',
#   'breed': 'Catahoula Mix',
#   'color': 'Brown Merle'},
#  {'animal_id': 'A664304',
#   'datetime': '2013-10-01T16:03:00.000',
#   'datetime2': '2013-10-01T16:03:00.000',
#   'found_location': '7903 Taza Trl in Austin (TX)',
#   'intake_type': 'Stray',
#   'intake_condition': 'Normal',
#   'animal_type': 'Cat',
#   'sex_upon_intake': 'Intact Male',
#   'age_upon_intake': '9 months',
#   'breed': 'Domestic Shorthair Mix',
#   'color': 'Orange Tabby'},
#  {'animal_id': 'A665737',
#   'name': '*Milo',
#   'datetime': '2013-10-22T10:46:00.000',
#   'datetime2': '2013-10-22T10:46:00.000',
#   'found_location': 'E Oltorf St/Douglas in Austin (TX)',
#   'intake_type': 'Stray',
#   'intake_condition': 'Normal',
#   'animal_type': 'Dog',
#   'sex_upon_intake': 'Intact Male',
#   'age_upon_intake': '1 year',
#   'breed': 'Dachshund Wirehair/Miniature Schnauzer',
#   'color': 'Black/Silver'},
#  {'animal_id': 'A665723',
#   'datetime': '2013-10-21T21:58:00.000',
#   'datetime2': '2013-10-21T21:58:00.000',
#   'found_location': '11501 Burnet Rd in Austin (TX)',
#   'intake_type': 'Stray',
#   'intake_condition': 'Injured',
#   'animal_type': 'Dog',
#   'sex_upon_intake': 'Intact Female',
#   'age_upon_intake': '2 years',
#   'breed': 'Golden Retriever/Standard Poodle',
#   'color': 'Buff'},
#  {'animal_id': 'A665676',
#   'datetime': '2013-10-21T15:19:00.000',
#   'datetime2': '2013-10-21T15:19:00.000',
#   'found_location': 'Outside Jurisdiction',
#   'intake_type': 'Stray',
#   'intake_condition': 'Normal',
#   'animal_type': 'Cat',
#   'sex_upon_intake': 'Intact Female',
#   'age_upon_intake': '3 days',
#   'breed': 'Domestic Shorthair Mix',
#   'color': 'Black Smoke'},
#  {'animal_id': 'A665490',
#   'name': 'Porky',
#   'datetime': '2013-10-23T12:46:00.000',
#   'datetime2': '2013-10-23T12:46:00.000',
#   'found_location': 'Austin (TX)',
#   'intake_type': 'Owner Surrender',
#   'intake_condition': 'Normal',
#   'animal_type': 'Dog',
#   'sex_upon_intake': 'Intact Male',
#   'age_upon_intake': '8 months',
#   'breed': 'Queensland Heeler Mix',
#   'color': 'Blue Merle'},
#  {'animal_id': 'A664501',
#   'name': 'Mittens',
#   'datetime': '2013-10-04T12:08:00.000',
#   'datetime2': '2013-10-04T12:08:00.000',
#   'found_location': 'Deidra Drive in Travis (TX)',
#   'intake_type': 'Stray',
#   'intake_condition': 'Normal',
#   'animal_type': 'Cat',
#   'sex_upon_intake': 'Intact Male',
#   'age_upon_intake': '2 months',
#   'breed': 'Domestic Shorthair Mix',
#   'color': 'Black/White'},
#  {'animal_id': 'A661789',
#   'name': 'Tank',
#   'datetime': '2013-10-16T21:37:00.000',
#   'datetime2': '2013-10-16T21:37:00.000',
#   'found_location': '7400 Geneva in Austin (TX)',
#   'intake_type': 'Stray',
#   'intake_condition': 'Normal',
#   'animal_type': 'Dog',
#   'sex_upon_intake': 'Neutered Male',
#   'age_upon_intake': '2 years',
#   'breed': 'Pit Bull Mix',
#   'color': 'Brown/White'},
#  {'animal_id': 'A665187',
#   'name': 'Coco',
#   'datetime': '2013-10-14T22:21:00.000',
#   'datetime2': '2013-10-14T22:21:00.000',
#   'found_location': '7304 Blessing Ave in Austin (TX)',
#   'intake_type': 'Stray',
#   'intake_condition': 'Normal',
#   'animal_type': 'Dog',
#   'sex_upon_intake': 'Intact Male',
#   'age_upon_intake': '2 years',
#   'breed': 'Pit Bull Mix',
#   'color': 'Black/White'},
#  {'animal_id': 'A636021',
#   'name': 'Sera',
#   'datetime': '2013-10-01T14:12:00.000',
#   'datetime2': '2013-10-01T14:12:00.000',
#   'found_location': '1156 W Cesar Chavez in Austin (TX)',
#   'intake_type': 'Public Assist',
#   'intake_condition': 'Normal',
#   'animal_type': 'Dog',
#   'sex_upon_intake': 'Spayed Female',
#   'age_upon_intake': '1 year',
#   'breed': 'Pit Bull Mix',
#   'color': 'Brown'},
#  {'animal_id': 'A665618',
#   'datetime': '2013-10-20T12:25:00.000',
#   'datetime2': '2013-10-20T12:25:00.000',
#   'found_location': '1815 Burton Dr in Austin (TX)',
#   'intake_type': 'Stray',
#   'intake_condition': 'Normal',
#   'animal_type': 'Cat',
#   'sex_upon_intake': 'Intact Female',
#   'age_upon_intake': '5 months',
#   'breed': 'Domestic Shorthair Mix',
#   'color': 'Calico/White'},
#  {'animal_id': 'A665498',
#   'name': 'Marbles',
#   'datetime': '2013-10-18T18:56:00.000',
#   'datetime2': '2013-10-18T18:56:00.000',
#   'found_location': '5502 Rose Hill Cir in Austin (TX)',
#   'intake_type': 'Owner Surrender',
#   'intake_condition': 'Normal',
#   'animal_type': 'Dog',
#   'sex_upon_intake': 'Spayed Female',
#   'age_upon_intake': '3 years',
#   'breed': 'Collie Smooth Mix',
#   'color': 'Blue Merle/Tan'},
#  {'animal_id': 'A664943',
#   'name': '*Leo',
#   'datetime': '2013-10-17T11:05:00.000',
#   'datetime2': '2013-10-17T11:05:00.000',
#   'found_location': 'Austin (TX)',
#   'intake_type': 'Owner Surrender',
#   'intake_condition': 'Normal',
#   'animal_type': 'Dog',
#   'sex_upon_intake': 'Neutered Male',
#   'age_upon_intake': '3 years',
#   'breed': 'Labrador Retriever Mix',
#   'color': 'Black'},
#  {'animal_id': 'A659035',
#   'name': 'Zoe',
#   'datetime': '2013-10-01T17:39:00.000',
#   'datetime2': '2013-10-01T17:39:00.000',
#   'found_location': 'Austin (TX)',
#   'intake_type': 'Owner Surrender',
#   'intake_condition': 'Normal',
#   'animal_type': 'Dog',
#   'sex_upon_intake': 'Spayed Female',
#   'age_upon_intake': '10 months',
#   'breed': 'Belgian Malinois Mix',
#   'color': 'Tan/White'},
#  {'animal_id': 'A665963',
#   'name': 'Evelyn',
#   'datetime': '2013-10-25T11:02:00.000',
#   'datetime2': '2013-10-25T11:02:00.000',
#   'found_location': '1203 York Castle Drive in Pflugerville (TX)',
#   'intake_type': 'Stray',
#   'intake_condition': 'Normal',
#   'animal_type': 'Cat',
#   'sex_upon_intake': 'Spayed Female',
#   'age_upon_intake': '2 years',
#   'breed': 'Domestic Shorthair Mix',
#   'color': 'Brown Tabby'},
#  {'animal_id': 'A659667',
#   'datetime': '2013-10-26T15:03:00.000',
#   'datetime2': '2013-10-26T15:03:00.000',
#   'found_location': '12507 Esplanade in Austin (TX)',
#   'intake_type': 'Stray',
#   'intake_condition': 'Normal',
#   'animal_type': 'Cat',
#   'sex_upon_intake': 'Neutered Male',
#   'age_upon_intake': '8 years',
#   'breed': 'Domestic Longhair Mix',
#   'color': 'Blue/White'},
#  {'animal_id': 'A664804',
#   'name': 'Titi',
#   'datetime': '2013-10-09T12:19:00.000',
#   'datetime2': '2013-10-09T12:19:00.000',
#   'found_location': '2703 Crownover St in Austin (TX)',
#   'intake_type': 'Stray',
#   'intake_condition': 'Normal',
#   'animal_type': 'Dog',
#   'sex_upon_intake': 'Intact Female',
#   'age_upon_intake': '2 years',
#   'breed': 'Chihuahua Shorthair Mix',
#   'color': 'Tan'},
#  {'animal_id': 'A664522',
#   'name': '*Lucy',
#   'datetime': '2013-10-04T17:32:00.000',
#   'datetime2': '2013-10-04T17:32:00.000',
#   'found_location': '9100 Meadow Green in Austin (TX)',
#   'intake_type': 'Stray',
#   'intake_condition': 'Normal',
#   'animal_type': 'Dog',
#   'sex_upon_intake': 'Intact Female',
#   'age_upon_intake': '1 year',
#   'breed': 'Chihuahua Shorthair Mix',
#   'color': 'White/Yellow'},
#  {'animal_id': 'A664869',
#   'name': '*Ollie',
#   'datetime': '2013-10-10T11:00:00.000',
#   'datetime2': '2013-10-10T11:00:00.000',
#   'found_location': 'Round Mtn & Bingham Cr Rd, Leander in Austin (TX)',
#   'intake_type': 'Stray',
#   'intake_condition': 'Normal',
#   'animal_type': 'Dog',
#   'sex_upon_intake': 'Intact Male',
#   'age_upon_intake': '3 years',
#   'breed': 'Australian Cattle Dog Mix',
#   'color': 'Red/White'},
#  {'animal_id': 'A664795',
#   'name': 'Zilla',
#   'datetime': '2013-10-09T11:02:00.000',
#   'datetime2': '2013-10-09T11:02:00.000',
#   'found_location': 'East 12Th in Austin (TX)',
#   'intake_type': 'Stray',
#   'intake_condition': 'Normal',
#   'animal_type': 'Dog',
#   'sex_upon_intake': 'Neutered Male',
#   'age_upon_intake': '10 months',
#   'breed': 'Yorkshire Terrier/Miniature Schnauzer',
#   'color': 'Gray/Tan'},
#  {'animal_id': 'A641317',
#   'name': '*Grace',
#   'datetime': '2013-10-16T13:11:00.000',
#   'datetime2': '2013-10-16T13:11:00.000',
#   'found_location': 'Austin (TX)',
#   'intake_type': 'Owner Surrender',
#   'intake_condition': 'Normal',
#   'animal_type': 'Dog',
#   'sex_upon_intake': 'Spayed Female',
#   'age_upon_intake': '3 years',
#   'breed': 'Collie Smooth/Golden Retriever',
#   'color': 'Red/White'},
#  {'animal_id': 'A665223',
#   'name': 'Boss',
#   'datetime': '2013-10-15T12:33:00.000',
#   'datetime2': '2013-10-15T12:33:00.000',
#   'found_location': 'Austin (TX)',
#   'intake_type': 'Owner Surrender',
#   'intake_condition': 'Normal',
#   'animal_type': 'Dog',
#   'sex_upon_intake': 'Intact Male',
#   'age_upon_intake': '1 year',
#   'breed': 'Golden Retriever',
#   'color': 'Gold/Buff'},
#  {'animal_id': 'A665621',
#   'name': '*Stoli',
#   'datetime': '2013-10-20T12:44:00.000',
#   'datetime2': '2013-10-20T12:44:00.000',
#   'found_location': '2850 Hwy 71 West in Travis (TX)',
#   'intake_type': 'Stray',
#   'intake_condition': 'Normal',
#   'animal_type': 'Dog',
#   'sex_upon_intake': 'Intact Male',
#   'age_upon_intake': '5 years',
#   'breed': 'Chihuahua Shorthair/Rat Terrier',
#   'color': 'Black/Brown Brindle'},
#  {'animal_id': 'A666054',
#   'datetime': '2013-10-26T14:04:00.000',
#   'datetime2': '2013-10-26T14:04:00.000',
#   'found_location': 'S Pleasant Valley And Wm Cannon in Austin (TX)',
#   'intake_type': 'Stray',
#   'intake_condition': 'Normal',
#   'animal_type': 'Dog',
#   'sex_upon_intake': 'Intact Female',
#   'age_upon_intake': '4 months',
#   'breed': 'Chihuahua Shorthair Mix',
#   'color': 'Black/Tan'},
#  {'animal_id': 'A665207',
#   'datetime': '2013-10-15T11:35:00.000',
#   'datetime2': '2013-10-15T11:35:00.000',
#   'found_location': '4216 S Congress Ave in Austin (TX)',
#   'intake_type': 'Stray',
#   'intake_condition': 'Normal',
#   'animal_type': 'Cat',
#   'sex_upon_intake': 'Intact Female',
#   'age_upon_intake': '2 weeks',
#   'breed': 'Domestic Shorthair Mix',
#   'color': 'Tortie'},
#  {'animal_id': 'A665230',
#   'name': 'Marley',
#   'datetime': '2013-10-15T14:35:00.000',
#   'datetime2': '2013-10-15T14:35:00.000',
#   'found_location': '7101 W. 71 Oak Hill Vet Clinic in Austin (TX)',
#   'intake_type': 'Stray',
#   'intake_condition': 'Normal',
#   'animal_type': 'Dog',
#   'sex_upon_intake': 'Intact Female',
#   'age_upon_intake': '3 years',
#   'breed': 'Labrador Retriever Mix',
#   'color': 'Yellow'},
#  {'animal_id': 'A664917',
#   'name': '*Big Otis',
#   'datetime': '2013-10-10T18:04:00.000',
#   'datetime2': '2013-10-10T18:04:00.000',
#   'found_location': '9707 Teasdale Terrace in Austin (TX)',
#   'intake_type': 'Stray',
#   'intake_condition': 'Normal',
#   'animal_type': 'Dog',
#   'sex_upon_intake': 'Intact Male',
#   'age_upon_intake': '4 years',
#   'breed': 'Labrador Retriever Mix',
#   'color': 'Yellow'},
#  {'animal_id': 'A633952',
#   'name': 'Maximus',
#   'datetime': '2013-10-05T12:28:00.000',
#   'datetime2': '2013-10-05T12:28:00.000',
#   'found_location': 'Austin (TX)',
#   'intake_type': 'Owner Surrender',
#   'intake_condition': 'Normal',
#   'animal_type': 'Dog',
#   'sex_upon_intake': 'Neutered Male',
#   'age_upon_intake': '2 years',
#   'breed': 'Pit Bull Mix',
#   'color': 'Tan/White'},
#  {'animal_id': 'A664268',
#   'name': '*Kochka',
#   'datetime': '2013-10-01T12:05:00.000',
#   'datetime2': '2013-10-01T12:05:00.000',
#   'found_location': 'Austin (TX)',
#   'intake_type': 'Stray',
#   'intake_condition': 'Normal',
#   'animal_type': 'Cat',
#   'sex_upon_intake': 'Intact Female',
#   'age_upon_intake': '3 years',
#   'breed': 'Russian Blue Mix',
#   'color': 'Blue'},
#  {'animal_id': 'A656696',
#   'name': '*Angel',
#   'datetime': '2013-10-13T12:52:00.000',
#   'datetime2': '2013-10-13T12:52:00.000',
#   'found_location': 'Austin (TX)',
#   'intake_type': 'Owner Surrender',
#   'intake_condition': 'Normal',
#   'animal_type': 'Cat',
#   'sex_upon_intake': 'Spayed Female',
#   'age_upon_intake': '2 years',
#   'breed': 'Domestic Shorthair Mix',
#   'color': 'Brown Tabby'},
#  {'animal_id': 'A665285',
#   'name': 'Tabby',
#   'datetime': '2013-10-15T18:19:00.000',
#   'datetime2': '2013-10-15T18:19:00.000',
#   'found_location': '4807 Airport Blvd in Austin (TX)',
#   'intake_type': 'Stray',
#   'intake_condition': 'Normal',
#   'animal_type': 'Cat',
#   'sex_upon_intake': 'Intact Female',
#   'age_upon_intake': '5 months',
#   'breed': 'Domestic Shorthair Mix',
#   'color': 'Torbie'},
#  {'animal_id': 'A665185',
#   'name': '*Vince',
#   'datetime': '2013-10-14T18:32:00.000',
#   'datetime2': '2013-10-14T18:32:00.000',
#   'found_location': 'Hwy 183/Burnet Rd in Austin (TX)',
#   'intake_type': 'Stray',
#   'intake_condition': 'Normal',
#   'animal_type': 'Cat',
#   'sex_upon_intake': 'Intact Male',
#   'age_upon_intake': '3 weeks',
#   'breed': 'Domestic Shorthair Mix',
#   'color': 'Brown Tabby/White'},
#  {'animal_id': 'A665572',
#   'datetime': '2013-10-19T14:09:00.000',
#   'datetime2': '2013-10-19T14:09:00.000',
#   'found_location': '900 Broken Feather Trl in Pflugerville (TX)',
#   'intake_type': 'Stray',
#   'intake_condition': 'Normal',
#   'animal_type': 'Dog',
#   'sex_upon_intake': 'Intact Male',
#   'age_upon_intake': '1 year',
#   'breed': 'Great Pyrenees Mix',
#   'color': 'White'}]

# %%
requests.get('https://data.austintexas.gov/resource/wter-evkm?$offset=200000').json()
# Out:
# []

# %%
url= 'https://data.austintexas.gov/resource/wter-evkm'
print(url)
# Out:
# https://data.austintexas.gov/resource/wter-evkm

# %%
x=1000

# %%
url = url + f'?$offset={x}'
print(url)
# Out:
# https://data.austintexas.gov/resource/wter-evkm?$offset=1000

# %%
def get_data(url, offset=1000):
    '''
    this function will return a dataFrame with all of the results from the passed url
    until the last page of results
    '''
    # create request.get for passed url
    page = requests.get(url)
    # create a dataframe withe the first page results
    df = pd.DataFrame(page.json())
    # set first offset amount
    x=offset
    # loop through all pages of results for passed url
    while page.json():
        # set the page url to the next page url
        next_url = url + f'?$offset={x}'
        page = requests.get(next_url)
        df = pd.concat([df, pd.DataFrame(page.json())], axis=0)
    # return the datframe
    return df.reset_index().drop(columns='index')

# %%
pd.DataFrame(request.json())
# Out:
#     animal_id                 datetime                datetime2  \
# 0     A665644  2013-10-21T07:59:00.000  2013-10-21T07:59:00.000
# 1     A665739  2013-10-22T11:11:00.000  2013-10-22T11:11:00.000
# 2     A665763  2013-10-22T15:10:00.000  2013-10-22T15:10:00.000
# 3     A379998  2013-10-23T11:42:00.000  2013-10-23T11:42:00.000
# 4     A634503  2013-10-01T14:49:00.000  2013-10-01T14:49:00.000
# ..        ...                      ...                      ...
# 995   A664268  2013-10-01T12:05:00.000  2013-10-01T12:05:00.000
# 996   A656696  2013-10-13T12:52:00.000  2013-10-13T12:52:00.000
# 997   A665285  2013-10-15T18:19:00.000  2013-10-15T18:19:00.000
# 998   A665185  2013-10-14T18:32:00.000  2013-10-14T18:32:00.000
# 999   A665572  2013-10-19T14:09:00.000  2013-10-19T14:09:00.000
#
#                                    found_location      intake_type  \
# 0                                     Austin (TX)            Stray
# 1                                     Austin (TX)            Stray
# 2    E Riverside Dr/Royal Crest Dr in Austin (TX)            Stray
# 3                  51St And Grover in Austin (TX)            Stray
# 4                                      Manor (TX)  Owner Surrender
# ..                                            ...              ...
# 995                                   Austin (TX)            Stray
# 996                                   Austin (TX)  Owner Surrender
# 997              4807 Airport Blvd in Austin (TX)            Stray
# 998              Hwy 183/Burnet Rd in Austin (TX)            Stray
# 999   900 Broken Feather Trl in Pflugerville (TX)            Stray
#
#     intake_condition animal_type sex_upon_intake age_upon_intake  \
# 0               Sick         Cat   Intact Female         4 weeks
# 1             Normal         Cat   Intact Female         1 month
# 2             Normal         Dog     Intact Male        4 months
# 3             Normal         Dog     Intact Male        10 years
# 4             Normal         Dog   Spayed Female         2 years
# ..               ...         ...             ...             ...
# 995           Normal         Cat   Intact Female         3 years
# 996           Normal         Cat   Spayed Female         2 years
# 997           Normal         Cat   Intact Female        5 months
# 998           Normal         Cat     Intact Male         3 weeks
# 999           Normal         Dog     Intact Male          1 year
#
#                         breed              color      name
# 0      Domestic Shorthair Mix             Calico       NaN
# 1    Domestic Medium Hair Mix              Black    *Alana
# 2           Cairn Terrier Mix          Tan/White       NaN
# 3                    Pit Bull              Black  Disciple
# 4         Norfolk Terrier Mix                Tan     Otter
# ..                        ...                ...       ...
# 995          Russian Blue Mix               Blue   *Kochka
# 996    Domestic Shorthair Mix        Brown Tabby    *Angel
# 997    Domestic Shorthair Mix             Torbie     Tabby
# 998    Domestic Shorthair Mix  Brown Tabby/White    *Vince
# 999        Great Pyrenees Mix              White       NaN
#
# [1000 rows x 12 columns]

# %%
intake_a = pd.DataFrame(request.json())

# %%
intake_a.datetime = pd.to_datetime(intake_a.datetime)

# %%
intake_a.head()
# Out:
#   animal_id            datetime                datetime2  \
# 0   A665644 2013-10-21 07:59:00  2013-10-21T07:59:00.000
# 1   A665739 2013-10-22 11:11:00  2013-10-22T11:11:00.000
# 2   A665763 2013-10-22 15:10:00  2013-10-22T15:10:00.000
# 3   A379998 2013-10-23 11:42:00  2013-10-23T11:42:00.000
# 4   A634503 2013-10-01 14:49:00  2013-10-01T14:49:00.000
#
#                                  found_location      intake_type  \
# 0                                   Austin (TX)            Stray
# 1                                   Austin (TX)            Stray
# 2  E Riverside Dr/Royal Crest Dr in Austin (TX)            Stray
# 3                51St And Grover in Austin (TX)            Stray
# 4                                    Manor (TX)  Owner Surrender
#
#   intake_condition animal_type sex_upon_intake age_upon_intake  \
# 0             Sick         Cat   Intact Female         4 weeks
# 1           Normal         Cat   Intact Female         1 month
# 2           Normal         Dog     Intact Male        4 months
# 3           Normal         Dog     Intact Male        10 years
# 4           Normal         Dog   Spayed Female         2 years
#
#                       breed      color      name
# 0    Domestic Shorthair Mix     Calico       NaN
# 1  Domestic Medium Hair Mix      Black    *Alana
# 2         Cairn Terrier Mix  Tan/White       NaN
# 3                  Pit Bull      Black  Disciple
# 4       Norfolk Terrier Mix        Tan     Otter

# %%
intake_a.datetime2 = pd.to_datetime(intake_a.datetime2)

# %%
pd.concat([intake_a.datetime2.dt.month_name(), intake_a.datetime2.dt.year], axis=1)
# Out:
#      datetime2  datetime2
# 0      October       2013
# 1      October       2013
# 2      October       2013
# 3      October       2013
# 4      October       2013
# ..         ...        ...
# 995    October       2013
# 996    October       2013
# 997    October       2013
# 998    October       2013
# 999    October       2013
#
# [1000 rows x 2 columns]

# %%
intakes.head()
# Out:
#   Animal ID      Name                DateTime     MonthYear  \
# 0   A665644       NaN  10/21/2013 07:59:00 AM  October 2013
# 1   A665739    *Alana  10/22/2013 11:11:00 AM  October 2013
# 2   A665763       NaN  10/22/2013 03:10:00 PM  October 2013
# 3   A379998  Disciple  10/23/2013 11:42:00 AM  October 2013
# 4   A634503     Otter  10/01/2013 02:49:00 PM  October 2013
#
#                                  Found Location      Intake Type  \
# 0                                   Austin (TX)            Stray
# 1                                   Austin (TX)            Stray
# 2  E Riverside Dr/Royal Crest Dr in Austin (TX)            Stray
# 3                51St And Grover in Austin (TX)            Stray
# 4                                    Manor (TX)  Owner Surrender
#
#   Intake Condition Animal Type Sex upon Intake Age upon Intake  \
# 0             Sick         Cat   Intact Female         4 weeks
# 1           Normal         Cat   Intact Female         1 month
# 2           Normal         Dog     Intact Male        4 months
# 3           Normal         Dog     Intact Male        10 years
# 4           Normal         Dog   Spayed Female         2 years
#
#                       Breed      Color
# 0    Domestic Shorthair Mix     Calico
# 1  Domestic Medium Hair Mix      Black
# 2         Cairn Terrier Mix  Tan/White
# 3                  Pit Bull      Black
# 4       Norfolk Terrier Mix        Tan

# %%
intakes.columns = intakes.columns.str.lower().str.replace(' ','_').to_list()
outcomes.columns = outcomes.columns.str.lower().str.replace(' ','_').to_list()

# %%
intakes.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150370 entries, 0 to 150369
# Data columns (total 12 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   animal_id         150370 non-null  object
#  1   name              106773 non-null  object
#  2   datetime          150370 non-null  object
#  3   monthyear         150370 non-null  object
#  4   found_location    150370 non-null  object
#  5   intake_type       150370 non-null  object
#  6   intake_condition  150370 non-null  object
#  7   animal_type       150370 non-null  object
#  8   sex_upon_intake   150368 non-null  object
#  9   age_upon_intake   150369 non-null  object
#  10  breed             150370 non-null  object
#  11  color             150370 non-null  object
# dtypes: object(12)
# memory usage: 13.8+ MB

# %%
outcomes.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150395 entries, 0 to 150394
# Data columns (total 12 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   animal_id         150395 non-null  object
#  1   name              106910 non-null  object
#  2   datetime          150395 non-null  object
#  3   monthyear         150395 non-null  object
#  4   date_of_birth     150395 non-null  object
#  5   outcome_type      150370 non-null  object
#  6   outcome_subtype   68904 non-null   object
#  7   animal_type       150395 non-null  object
#  8   sex_upon_outcome  150393 non-null  object
#  9   age_upon_outcome  150348 non-null  object
#  10  breed             150395 non-null  object
#  11  color             150395 non-null  object
# dtypes: object(12)
# memory usage: 13.8+ MB

# %%
animals = pd.merge(left=intakes, right=outcomes, how='inner', on='animal_id',
                   suffixes=('_in','_out'))

# %%
animals.head()
# Out:
#   animal_id   name_in             datetime_in  monthyear_in  \
# 0   A665644       NaN  10/21/2013 07:59:00 AM  October 2013
# 1   A665739    *Alana  10/22/2013 11:11:00 AM  October 2013
# 2   A665763       NaN  10/22/2013 03:10:00 PM  October 2013
# 3   A379998  Disciple  10/23/2013 11:42:00 AM  October 2013
# 4   A634503     Otter  10/01/2013 02:49:00 PM  October 2013
#
#                                  found_location      intake_type  \
# 0                                   Austin (TX)            Stray
# 1                                   Austin (TX)            Stray
# 2  E Riverside Dr/Royal Crest Dr in Austin (TX)            Stray
# 3                51St And Grover in Austin (TX)            Stray
# 4                                    Manor (TX)  Owner Surrender
#
#   intake_condition animal_type_in sex_upon_intake age_upon_intake  ...  \
# 0             Sick            Cat   Intact Female         4 weeks  ...
# 1           Normal            Cat   Intact Female         1 month  ...
# 2           Normal            Dog     Intact Male        4 months  ...
# 3           Normal            Dog     Intact Male        10 years  ...
# 4           Normal            Dog   Spayed Female         2 years  ...
#
#              datetime_out monthyear_out date_of_birth     outcome_type  \
# 0  10/21/2013 11:39:00 AM      Oct 2013    09/21/2013         Transfer
# 1  12/20/2013 05:36:00 PM      Dec 2013    09/16/2013         Adoption
# 2  10/26/2013 06:32:00 PM      Oct 2013    06/22/2013         Adoption
# 3  10/25/2013 12:53:00 PM      Oct 2013    02/21/2003  Return to Owner
# 4  10/02/2013 12:40:00 PM      Oct 2013    08/11/2011         Adoption
#
#   outcome_subtype animal_type_out sex_upon_outcome age_upon_outcome  \
# 0         Partner             Cat    Intact Female          4 weeks
# 1          Foster             Cat    Spayed Female         3 months
# 2             NaN             Dog    Neutered Male         4 months
# 3             NaN             Dog      Intact Male         10 years
# 4             NaN             Dog    Spayed Female          2 years
#
#                   breed_out  color_out
# 0    Domestic Shorthair Mix     Calico
# 1  Domestic Medium Hair Mix      Black
# 2         Cairn Terrier Mix  Tan/White
# 3                  Pit Bull      Black
# 4       Norfolk Terrier Mix        Tan
#
# [5 rows x 23 columns]

# %%
animals.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 193118 entries, 0 to 193117
# Data columns (total 23 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   animal_id         193118 non-null  object
#  1   name_in           148817 non-null  object
#  2   datetime_in       193118 non-null  object
#  3   monthyear_in      193118 non-null  object
#  4   found_location    193118 non-null  object
#  5   intake_type       193118 non-null  object
#  6   intake_condition  193118 non-null  object
#  7   animal_type_in    193118 non-null  object
#  8   sex_upon_intake   193116 non-null  object
#  9   age_upon_intake   193117 non-null  object
#  10  breed_in          193118 non-null  object
#  11  color_in          193118 non-null  object
#  12  name_out          148817 non-null  object
#  13  datetime_out      193118 non-null  object
#  14  monthyear_out     193118 non-null  object
#  15  date_of_birth     193118 non-null  object
#  16  outcome_type      193082 non-null  object
#  17  outcome_subtype   75665 non-null   object
#  18  animal_type_out   193118 non-null  object
#  19  sex_upon_outcome  193116 non-null  object
#  20  age_upon_outcome  193071 non-null  object
#  21  breed_out         193118 non-null  object
#  22  color_out         193118 non-null  object
# dtypes: object(23)
# memory usage: 35.4+ MB

# %%
animals.name_in == animals.name_out
# Out:
# 0         False
# 1          True
# 2         False
# 3          True
# 4          True
#           ...
# 193113     True
# 193114     True
# 193115     True
# 193116     True
# 193117     True
# Length: 193118, dtype: bool

# %%
animals = animals.drop(columns=['monthyear_in', 'monthyear_out'])

# %%
animals.head()
# Out:
#   animal_id   name_in             datetime_in  \
# 0   A665644       NaN  10/21/2013 07:59:00 AM
# 1   A665739    *Alana  10/22/2013 11:11:00 AM
# 2   A665763       NaN  10/22/2013 03:10:00 PM
# 3   A379998  Disciple  10/23/2013 11:42:00 AM
# 4   A634503     Otter  10/01/2013 02:49:00 PM
#
#                                  found_location      intake_type  \
# 0                                   Austin (TX)            Stray
# 1                                   Austin (TX)            Stray
# 2  E Riverside Dr/Royal Crest Dr in Austin (TX)            Stray
# 3                51St And Grover in Austin (TX)            Stray
# 4                                    Manor (TX)  Owner Surrender
#
#   intake_condition animal_type_in sex_upon_intake age_upon_intake  \
# 0             Sick            Cat   Intact Female         4 weeks
# 1           Normal            Cat   Intact Female         1 month
# 2           Normal            Dog     Intact Male        4 months
# 3           Normal            Dog     Intact Male        10 years
# 4           Normal            Dog   Spayed Female         2 years
#
#                    breed_in  ...  name_out            datetime_out  \
# 0    Domestic Shorthair Mix  ...       NaN  10/21/2013 11:39:00 AM
# 1  Domestic Medium Hair Mix  ...    *Alana  12/20/2013 05:36:00 PM
# 2         Cairn Terrier Mix  ...       NaN  10/26/2013 06:32:00 PM
# 3                  Pit Bull  ...  Disciple  10/25/2013 12:53:00 PM
# 4       Norfolk Terrier Mix  ...     Otter  10/02/2013 12:40:00 PM
#
#   date_of_birth     outcome_type outcome_subtype animal_type_out  \
# 0    09/21/2013         Transfer         Partner             Cat
# 1    09/16/2013         Adoption          Foster             Cat
# 2    06/22/2013         Adoption             NaN             Dog
# 3    02/21/2003  Return to Owner             NaN             Dog
# 4    08/11/2011         Adoption             NaN             Dog
#
#   sex_upon_outcome age_upon_outcome                 breed_out  color_out
# 0    Intact Female          4 weeks    Domestic Shorthair Mix     Calico
# 1    Spayed Female         3 months  Domestic Medium Hair Mix      Black
# 2    Neutered Male         4 months         Cairn Terrier Mix  Tan/White
# 3      Intact Male         10 years                  Pit Bull      Black
# 4    Spayed Female          2 years       Norfolk Terrier Mix        Tan
#
# [5 rows x 21 columns]

# %%
animals.shape
# Out:
# (193118, 23)

# %%
animals.animal_id.nunique()
# Out:
# 133921

# %%
animals.animal_id.value_counts().sort_values()
# Out:
# A717160       1
# A732194       1
# A844725       1
# A741841       1
# A737046       1
#            ...
# A700407      81
# A706536     121
# A718877     144
# A718223     196
# A721033    1089
# Name: animal_id, Length: 133921, dtype: int64

# %%
# repeats = animals[animals.animal_id.value_counts().sort_values() > 1]

# %%
len(intakes[intakes.animal_id == 'A721033'])
# Out:
# 33

# %%
len(outcomes[outcomes.animal_id == 'A721033'])
# Out:
# 33

# %%
intakes[intakes.animal_id == 'A721033']
# Out:
#        animal_id     name                datetime       monthyear  \
# 6601     A721033  Lil Bit  02/24/2019 09:53:00 PM   February 2019
# 14155    A721033  Lil Bit  03/07/2018 08:27:00 AM      March 2018
# 16598    A721033  Lil Bit  05/20/2019 10:18:00 AM        May 2019
# 17205    A721033  Lil Bit  04/05/2018 05:59:00 PM      April 2018
# 25150    A721033  Lil Bit  09/24/2018 07:44:00 PM  September 2018
# 29646    A721033  Lil Bit  03/15/2017 09:24:00 AM      March 2017
# 31643    A721033  Lil Bit  02/12/2019 10:21:00 AM   February 2019
# 32254    A721033  Lil Bit  10/20/2016 10:47:00 PM    October 2016
# 33464    A721033  Lil Bit  09/21/2018 03:01:00 PM  September 2018
# 33858    A721033  Lil Bit  10/05/2019 12:31:00 PM    October 2019
# 40101    A721033  Lil Bit  07/10/2016 11:53:00 AM       July 2016
# 43826    A721033  Lil Bit  08/05/2019 10:52:00 AM     August 2019
# 45489    A721033  Lil Bit  12/15/2016 10:07:00 AM   December 2016
# 46642    A721033  Lil Bit  09/03/2018 05:24:00 PM  September 2018
# 49040    A721033  Lil Bit  03/07/2019 12:02:00 PM      March 2019
# 49756    A721033  Lil Bit  01/30/2017 11:05:00 PM    January 2017
# 61810    A721033  Lil Bit  03/14/2018 10:57:00 AM      March 2018
# 62236    A721033  Lil Bit  04/26/2019 10:28:00 AM      April 2019
# 62907    A721033  Lil Bit  04/12/2018 10:14:00 AM      April 2018
# 70650    A721033  Lil Bit  02/16/2019 10:30:00 AM   February 2019
# 76775    A721033  Lil Bit  12/17/2018 04:52:00 PM   December 2018
# 86105    A721033  Lil Bit  04/22/2018 02:40:00 PM      April 2018
# 99735    A721033  Lil Bit  11/19/2018 07:53:00 PM   November 2018
# 104431   A721033  Lil Bit  02/20/2016 10:44:00 AM   February 2016
# 110755   A721033  Lil Bit  02/06/2017 10:13:00 AM   February 2017
# 116479   A721033  Lil Bit  09/16/2019 02:06:00 PM  September 2019
# 118733   A721033  Lil Bit  05/22/2018 01:48:00 PM        May 2018
# 119532   A721033  Lil Bit  01/09/2017 02:26:00 PM    January 2017
# 122887   A721033  Lil Bit  09/03/2016 02:30:00 PM  September 2016
# 126910   A721033  Lil Bit  01/26/2017 06:55:00 AM    January 2017
# 138243   A721033  Lil Bit  08/06/2018 07:00:00 PM     August 2018
# 144393   A721033  Lil Bit  08/18/2018 09:45:00 PM     August 2018
# 146338   A721033  Lil Bit  02/22/2018 10:28:00 AM   February 2018
#
#                                            found_location    intake_type  \
# 6601                          700 Allen St in Austin (TX)  Public Assist
# 14155                       4111 South 1St in Austin (TX)  Public Assist
# 16598      1819 South Pleasant Valley Road in Austin (TX)  Public Assist
# 17205                   9705 Manchaca Road in Austin (TX)  Public Assist
# 25150                    Shady And Airport in Austin (TX)  Public Assist
# 29646     E Ben White Blvd & Montopolis Dr in Austin (TX)  Public Assist
# 31643              1936 East Oltorf Street in Austin (TX)  Public Assist
# 32254               6200 E. Ben White Blvd in Austin (TX)  Public Assist
# 33464                     863 Airport Blvd in Austin (TX)  Public Assist
# 33858               1135 Airport Boulevard in Austin (TX)  Public Assist
# 40101                6317 E Ben White Blvd in Austin (TX)          Stray
# 43826                    Burton And Oltorf in Austin (TX)  Public Assist
# 45489   S Pleasant Valley Rd And E Riverside Dr in Aus...  Public Assist
# 46642   East 7Th Street And Pleasant Valley in Austin ...  Public Assist
# 49040                       1500 Red River in Austin (TX)  Public Assist
# 49756                     6210 E Ben White in Austin (TX)  Public Assist
# 61810                     814 Stark Street in Austin (TX)          Stray
# 62236               South 1St And Stassney in Austin (TX)  Public Assist
# 62907                                         Austin (TX)  Public Assist
# 70650                    1135 Airport Blvd in Austin (TX)  Public Assist
# 76775                         1144 Airport in Austin (TX)  Public Assist
# 86105   South First Street And Oltorf Street in Austin...          Stray
# 99735                         9300 S Ih 35 in Austin (TX)  Public Assist
# 104431                 2508 E Riverside Dr in Austin (TX)          Stray
# 110755                    6210 E Ben White in Austin (TX)  Public Assist
# 116479         Justin Lane And North Lamar in Austin (TX)  Public Assist
# 118733               W Oltorf And S 1St St in Austin (TX)  Public Assist
# 119532               6210 E Ben White Blvd in Austin (TX)          Stray
# 122887                    6010 E Riverside in Austin (TX)  Public Assist
# 126910                901 W Ben White Blvd in Austin (TX)  Public Assist
# 138243                  606 West Slaughter in Austin (TX)  Public Assist
# 144393               1500 Red River Street in Austin (TX)  Public Assist
# 146338                 6400 Ben White Blvd in Austin (TX)  Public Assist
#
#        intake_condition animal_type sex_upon_intake age_upon_intake  \
# 6601             Normal         Dog   Neutered Male         3 years
# 14155            Normal         Dog   Neutered Male         2 years
# 16598            Normal         Dog   Neutered Male         4 years
# 17205            Normal         Dog   Neutered Male         2 years
# 25150            Normal         Dog   Neutered Male         3 years
# 29646            Normal         Dog   Neutered Male          1 year
# 31643            Normal         Dog   Neutered Male         3 years
# 32254            Normal         Dog   Neutered Male          1 year
# 33464            Normal         Dog   Neutered Male         3 years
# 33858            Normal         Dog   Neutered Male         4 years
# 40101            Normal         Dog   Neutered Male          1 year
# 43826            Normal         Dog   Neutered Male         4 years
# 45489            Normal         Dog   Neutered Male          1 year
# 46642            Normal         Dog   Neutered Male         3 years
# 49040            Normal         Dog   Neutered Male         3 years
# 49756            Normal         Dog   Neutered Male          1 year
# 61810            Normal         Dog   Neutered Male         2 years
# 62236            Normal         Dog   Neutered Male         3 years
# 62907            Normal         Dog   Neutered Male         2 years
# 70650            Normal         Dog   Neutered Male         3 years
# 76775            Normal         Dog   Neutered Male         3 years
# 86105            Normal         Dog   Neutered Male         2 years
# 99735            Normal         Dog   Neutered Male         3 years
# 104431           Normal         Dog   Neutered Male        9 months
# 110755           Normal         Dog   Neutered Male          1 year
# 116479           Normal         Dog   Neutered Male         4 years
# 118733           Normal         Dog   Neutered Male         3 years
# 119532          Injured         Dog   Neutered Male          1 year
# 122887           Normal         Dog   Neutered Male          1 year
# 126910           Normal         Dog   Neutered Male          1 year
# 138243           Normal         Dog   Neutered Male         3 years
# 144393           Normal         Dog   Neutered Male         3 years
# 146338           Normal         Dog   Neutered Male         2 years
#
#                   breed                   color
# 6601    Rat Terrier Mix  Tricolor/Brown Brindle
# 14155   Rat Terrier Mix  Tricolor/Brown Brindle
# 16598   Rat Terrier Mix  Tricolor/Brown Brindle
# 17205   Rat Terrier Mix  Tricolor/Brown Brindle
# 25150   Rat Terrier Mix  Tricolor/Brown Brindle
# 29646   Rat Terrier Mix  Tricolor/Brown Brindle
# 31643   Rat Terrier Mix  Tricolor/Brown Brindle
# 32254   Rat Terrier Mix  Tricolor/Brown Brindle
# 33464   Rat Terrier Mix  Tricolor/Brown Brindle
# 33858   Rat Terrier Mix  Tricolor/Brown Brindle
# 40101   Rat Terrier Mix  Tricolor/Brown Brindle
# 43826   Rat Terrier Mix  Tricolor/Brown Brindle
# 45489   Rat Terrier Mix  Tricolor/Brown Brindle
# 46642   Rat Terrier Mix  Tricolor/Brown Brindle
# 49040   Rat Terrier Mix  Tricolor/Brown Brindle
# 49756   Rat Terrier Mix  Tricolor/Brown Brindle
# 61810   Rat Terrier Mix  Tricolor/Brown Brindle
# 62236   Rat Terrier Mix  Tricolor/Brown Brindle
# 62907   Rat Terrier Mix  Tricolor/Brown Brindle
# 70650   Rat Terrier Mix  Tricolor/Brown Brindle
# 76775   Rat Terrier Mix  Tricolor/Brown Brindle
# 86105   Rat Terrier Mix  Tricolor/Brown Brindle
# 99735   Rat Terrier Mix  Tricolor/Brown Brindle
# 104431  Rat Terrier Mix  Tricolor/Brown Brindle
# 110755  Rat Terrier Mix  Tricolor/Brown Brindle
# 116479  Rat Terrier Mix  Tricolor/Brown Brindle
# 118733  Rat Terrier Mix  Tricolor/Brown Brindle
# 119532  Rat Terrier Mix  Tricolor/Brown Brindle
# 122887  Rat Terrier Mix  Tricolor/Brown Brindle
# 126910  Rat Terrier Mix  Tricolor/Brown Brindle
# 138243  Rat Terrier Mix  Tricolor/Brown Brindle
# 144393  Rat Terrier Mix  Tricolor/Brown Brindle
# 146338  Rat Terrier Mix  Tricolor/Brown Brindle

# %%
outcomes[outcomes.animal_id == 'A721033']
# Out:
#        animal_id     name                datetime monthyear date_of_birth  \
# 4811     A721033  Lil Bit  08/10/2019 11:56:00 AM  Aug 2019    05/20/2015
# 10690    A721033  Lil Bit  01/10/2017 04:20:00 PM  Jan 2017    05/20/2015
# 13474    A721033  Lil Bit  10/21/2016 06:55:00 PM  Oct 2016    05/20/2015
# 16272    A721033  Lil Bit  03/11/2019 04:27:00 PM  Mar 2019    05/20/2015
# 19171    A721033  Lil Bit  05/21/2019 02:42:00 PM  May 2019    05/20/2015
# 23727    A721033  Lil Bit  11/24/2018 04:25:00 PM  Nov 2018    05/20/2015
# 26653    A721033  Lil Bit  03/16/2018 04:04:00 PM  Mar 2018    05/20/2015
# 30401    A721033  Lil Bit  05/04/2019 08:37:00 AM  May 2019    05/20/2015
# 35824    A721033  Lil Bit  02/18/2019 04:46:00 PM  Feb 2019    05/20/2015
# 40416    A721033  Lil Bit  01/28/2017 03:22:00 PM  Jan 2017    05/20/2015
# 41197    A721033  Lil Bit  08/22/2018 01:21:00 PM  Aug 2018    05/20/2015
# 49050    A721033  Lil Bit  04/24/2018 04:12:00 PM  Apr 2018    05/20/2015
# 49298    A721033  Lil Bit  02/26/2019 07:00:00 PM  Feb 2019    05/20/2015
# 52288    A721033  Lil Bit  09/25/2018 06:14:00 PM  Sep 2018    05/20/2015
# 56374    A721033  Lil Bit  04/11/2018 12:37:00 PM  Apr 2018    05/20/2015
# 64264    A721033  Lil Bit  02/07/2017 05:26:00 PM  Feb 2017    05/20/2015
# 64523    A721033  Lil Bit  09/19/2019 11:02:00 AM  Sep 2019    05/20/2015
# 65669    A721033  Lil Bit  08/09/2018 11:13:00 AM  Aug 2018    05/20/2015
# 65728    A721033  Lil Bit  07/11/2016 05:44:00 PM  Jul 2016    05/20/2015
# 69246    A721033  Lil Bit  10/20/2019 11:35:00 AM  Oct 2019    05/20/2015
# 70309    A721033  Lil Bit  02/20/2016 04:18:00 PM  Feb 2016    05/20/2015
# 78417    A721033  Lil Bit  02/02/2017 11:19:00 AM  Feb 2017    05/20/2015
# 78671    A721033  Lil Bit  09/23/2018 02:22:00 PM  Sep 2018    05/20/2015
# 83349    A721033  Lil Bit  09/08/2018 01:55:00 PM  Sep 2018    05/20/2015
# 85295    A721033  Lil Bit  02/23/2018 01:06:00 PM  Feb 2018    05/20/2015
# 88850    A721033  Lil Bit  12/27/2018 03:41:00 PM  Dec 2018    05/20/2015
# 89673    A721033  Lil Bit  03/16/2017 12:50:00 PM  Mar 2017    05/20/2015
# 92369    A721033  Lil Bit  12/16/2016 11:32:00 AM  Dec 2016    05/20/2015
# 93656    A721033  Lil Bit  09/12/2016 01:40:00 PM  Sep 2016    05/20/2015
# 102190   A721033  Lil Bit  03/08/2018 03:04:00 PM  Mar 2018    05/20/2015
# 121894   A721033  Lil Bit  04/17/2018 11:07:00 AM  Apr 2018    05/20/2015
# 127362   A721033  Lil Bit  02/12/2019 03:20:00 PM  Feb 2019    05/20/2015
# 130827   A721033  Lil Bit  05/26/2018 03:52:00 PM  May 2018    05/20/2015
#
#            outcome_type outcome_subtype animal_type sex_upon_outcome  \
# 4811    Return to Owner             NaN         Dog    Neutered Male
# 10690   Return to Owner             NaN         Dog    Neutered Male
# 13474   Return to Owner             NaN         Dog    Neutered Male
# 16272   Return to Owner             NaN         Dog    Neutered Male
# 19171   Return to Owner             NaN         Dog    Neutered Male
# 23727   Return to Owner             NaN         Dog    Neutered Male
# 26653   Return to Owner             NaN         Dog    Neutered Male
# 30401   Return to Owner             NaN         Dog    Neutered Male
# 35824   Return to Owner             NaN         Dog    Neutered Male
# 40416   Return to Owner             NaN         Dog    Neutered Male
# 41197   Return to Owner             NaN         Dog    Neutered Male
# 49050   Return to Owner             NaN         Dog    Neutered Male
# 49298   Return to Owner             NaN         Dog    Neutered Male
# 52288   Return to Owner             NaN         Dog    Neutered Male
# 56374   Return to Owner             NaN         Dog    Neutered Male
# 64264   Return to Owner             NaN         Dog    Neutered Male
# 64523   Return to Owner             NaN         Dog    Neutered Male
# 65669   Return to Owner             NaN         Dog    Neutered Male
# 65728   Return to Owner             NaN         Dog    Neutered Male
# 69246         Rto-Adopt             NaN         Dog    Neutered Male
# 70309   Return to Owner             NaN         Dog    Neutered Male
# 78417   Return to Owner             NaN         Dog    Neutered Male
# 78671   Return to Owner             NaN         Dog    Neutered Male
# 83349   Return to Owner             NaN         Dog    Neutered Male
# 85295   Return to Owner             NaN         Dog    Neutered Male
# 88850         Rto-Adopt             NaN         Dog    Neutered Male
# 89673   Return to Owner             NaN         Dog    Neutered Male
# 92369   Return to Owner             NaN         Dog    Neutered Male
# 93656   Return to Owner             NaN         Dog    Neutered Male
# 102190  Return to Owner             NaN         Dog    Neutered Male
# 121894  Return to Owner             NaN         Dog    Neutered Male
# 127362  Return to Owner             NaN         Dog    Neutered Male
# 130827  Return to Owner             NaN         Dog    Neutered Male
#
#        age_upon_outcome            breed                   color
# 4811            4 years  Rat Terrier Mix  Tricolor/Brown Brindle
# 10690            1 year  Rat Terrier Mix  Tricolor/Brown Brindle
# 13474            1 year  Rat Terrier Mix  Tricolor/Brown Brindle
# 16272           3 years  Rat Terrier Mix  Tricolor/Brown Brindle
# 19171           4 years  Rat Terrier Mix  Tricolor/Brown Brindle
# 23727           3 years  Rat Terrier Mix  Tricolor/Brown Brindle
# 26653           2 years  Rat Terrier Mix  Tricolor/Brown Brindle
# 30401           3 years  Rat Terrier Mix  Tricolor/Brown Brindle
# 35824           3 years  Rat Terrier Mix  Tricolor/Brown Brindle
# 40416            1 year  Rat Terrier Mix  Tricolor/Brown Brindle
# 41197           3 years  Rat Terrier Mix  Tricolor/Brown Brindle
# 49050           2 years  Rat Terrier Mix  Tricolor/Brown Brindle
# 49298           3 years  Rat Terrier Mix  Tricolor/Brown Brindle
# 52288           3 years  Rat Terrier Mix  Tricolor/Brown Brindle
# 56374           2 years  Rat Terrier Mix  Tricolor/Brown Brindle
# 64264            1 year  Rat Terrier Mix  Tricolor/Brown Brindle
# 64523           4 years  Rat Terrier Mix  Tricolor/Brown Brindle
# 65669           3 years  Rat Terrier Mix  Tricolor/Brown Brindle
# 65728            1 year  Rat Terrier Mix  Tricolor/Brown Brindle
# 69246           4 years  Rat Terrier Mix  Tricolor/Brown Brindle
# 70309          9 months  Rat Terrier Mix  Tricolor/Brown Brindle
# 78417            1 year  Rat Terrier Mix  Tricolor/Brown Brindle
# 78671           3 years  Rat Terrier Mix  Tricolor/Brown Brindle
# 83349           3 years  Rat Terrier Mix  Tricolor/Brown Brindle
# 85295           2 years  Rat Terrier Mix  Tricolor/Brown Brindle
# 88850           3 years  Rat Terrier Mix  Tricolor/Brown Brindle
# 89673            1 year  Rat Terrier Mix  Tricolor/Brown Brindle
# 92369            1 year  Rat Terrier Mix  Tricolor/Brown Brindle
# 93656            1 year  Rat Terrier Mix  Tricolor/Brown Brindle
# 102190          2 years  Rat Terrier Mix  Tricolor/Brown Brindle
# 121894          2 years  Rat Terrier Mix  Tricolor/Brown Brindle
# 127362          3 years  Rat Terrier Mix  Tricolor/Brown Brindle
# 130827          3 years  Rat Terrier Mix  Tricolor/Brown Brindle

# %%
lil_bit = animals[animals.animal_id == 'A721033']

# %%
lil_bit
# Out:
#       animal_id  name_in             datetime_in   monthyear_in  \
# 12649   A721033  Lil Bit  02/24/2019 09:53:00 PM  February 2019
# 12650   A721033  Lil Bit  02/24/2019 09:53:00 PM  February 2019
# 12651   A721033  Lil Bit  02/24/2019 09:53:00 PM  February 2019
# 12652   A721033  Lil Bit  02/24/2019 09:53:00 PM  February 2019
# 12653   A721033  Lil Bit  02/24/2019 09:53:00 PM  February 2019
# ...         ...      ...                     ...            ...
# 13733   A721033  Lil Bit  02/22/2018 10:28:00 AM  February 2018
# 13734   A721033  Lil Bit  02/22/2018 10:28:00 AM  February 2018
# 13735   A721033  Lil Bit  02/22/2018 10:28:00 AM  February 2018
# 13736   A721033  Lil Bit  02/22/2018 10:28:00 AM  February 2018
# 13737   A721033  Lil Bit  02/22/2018 10:28:00 AM  February 2018
#
#                            found_location    intake_type intake_condition  \
# 12649         700 Allen St in Austin (TX)  Public Assist           Normal
# 12650         700 Allen St in Austin (TX)  Public Assist           Normal
# 12651         700 Allen St in Austin (TX)  Public Assist           Normal
# 12652         700 Allen St in Austin (TX)  Public Assist           Normal
# 12653         700 Allen St in Austin (TX)  Public Assist           Normal
# ...                                   ...            ...              ...
# 13733  6400 Ben White Blvd in Austin (TX)  Public Assist           Normal
# 13734  6400 Ben White Blvd in Austin (TX)  Public Assist           Normal
# 13735  6400 Ben White Blvd in Austin (TX)  Public Assist           Normal
# 13736  6400 Ben White Blvd in Austin (TX)  Public Assist           Normal
# 13737  6400 Ben White Blvd in Austin (TX)  Public Assist           Normal
#
#       animal_type_in sex_upon_intake age_upon_intake  ...  \
# 12649            Dog   Neutered Male         3 years  ...
# 12650            Dog   Neutered Male         3 years  ...
# 12651            Dog   Neutered Male         3 years  ...
# 12652            Dog   Neutered Male         3 years  ...
# 12653            Dog   Neutered Male         3 years  ...
# ...              ...             ...             ...  ...
# 13733            Dog   Neutered Male         2 years  ...
# 13734            Dog   Neutered Male         2 years  ...
# 13735            Dog   Neutered Male         2 years  ...
# 13736            Dog   Neutered Male         2 years  ...
# 13737            Dog   Neutered Male         2 years  ...
#
#                  datetime_out monthyear_out date_of_birth     outcome_type  \
# 12649  08/10/2019 11:56:00 AM      Aug 2019    05/20/2015  Return to Owner
# 12650  01/10/2017 04:20:00 PM      Jan 2017    05/20/2015  Return to Owner
# 12651  10/21/2016 06:55:00 PM      Oct 2016    05/20/2015  Return to Owner
# 12652  03/11/2019 04:27:00 PM      Mar 2019    05/20/2015  Return to Owner
# 12653  05/21/2019 02:42:00 PM      May 2019    05/20/2015  Return to Owner
# ...                       ...           ...           ...              ...
# 13733  09/12/2016 01:40:00 PM      Sep 2016    05/20/2015  Return to Owner
# 13734  03/08/2018 03:04:00 PM      Mar 2018    05/20/2015  Return to Owner
# 13735  04/17/2018 11:07:00 AM      Apr 2018    05/20/2015  Return to Owner
# 13736  02/12/2019 03:20:00 PM      Feb 2019    05/20/2015  Return to Owner
# 13737  05/26/2018 03:52:00 PM      May 2018    05/20/2015  Return to Owner
#
#       outcome_subtype animal_type_out sex_upon_outcome age_upon_outcome  \
# 12649             NaN             Dog    Neutered Male          4 years
# 12650             NaN             Dog    Neutered Male           1 year
# 12651             NaN             Dog    Neutered Male           1 year
# 12652             NaN             Dog    Neutered Male          3 years
# 12653             NaN             Dog    Neutered Male          4 years
# ...               ...             ...              ...              ...
# 13733             NaN             Dog    Neutered Male           1 year
# 13734             NaN             Dog    Neutered Male          2 years
# 13735             NaN             Dog    Neutered Male          2 years
# 13736             NaN             Dog    Neutered Male          3 years
# 13737             NaN             Dog    Neutered Male          3 years
#
#              breed_out               color_out
# 12649  Rat Terrier Mix  Tricolor/Brown Brindle
# 12650  Rat Terrier Mix  Tricolor/Brown Brindle
# 12651  Rat Terrier Mix  Tricolor/Brown Brindle
# 12652  Rat Terrier Mix  Tricolor/Brown Brindle
# 12653  Rat Terrier Mix  Tricolor/Brown Brindle
# ...                ...                     ...
# 13733  Rat Terrier Mix  Tricolor/Brown Brindle
# 13734  Rat Terrier Mix  Tricolor/Brown Brindle
# 13735  Rat Terrier Mix  Tricolor/Brown Brindle
# 13736  Rat Terrier Mix  Tricolor/Brown Brindle
# 13737  Rat Terrier Mix  Tricolor/Brown Brindle
#
# [1089 rows x 23 columns]

# %%
lil_bit.datetime_in.value_counts()
# Out:
# 02/24/2019 09:53:00 PM    33
# 04/26/2019 10:28:00 AM    33
# 08/18/2018 09:45:00 PM    33
# 08/06/2018 07:00:00 PM    33
# 01/26/2017 06:55:00 AM    33
# 09/03/2016 02:30:00 PM    33
# 01/09/2017 02:26:00 PM    33
# 05/22/2018 01:48:00 PM    33
# 09/16/2019 02:06:00 PM    33
# 02/06/2017 10:13:00 AM    33
# 02/20/2016 10:44:00 AM    33
# 11/19/2018 07:53:00 PM    33
# 04/22/2018 02:40:00 PM    33
# 12/17/2018 04:52:00 PM    33
# 02/16/2019 10:30:00 AM    33
# 04/12/2018 10:14:00 AM    33
# 03/14/2018 10:57:00 AM    33
# 03/07/2018 08:27:00 AM    33
# 01/30/2017 11:05:00 PM    33
# 03/07/2019 12:02:00 PM    33
# 09/03/2018 05:24:00 PM    33
# 12/15/2016 10:07:00 AM    33
# 08/05/2019 10:52:00 AM    33
# 07/10/2016 11:53:00 AM    33
# 10/05/2019 12:31:00 PM    33
# 09/21/2018 03:01:00 PM    33
# 10/20/2016 10:47:00 PM    33
# 02/12/2019 10:21:00 AM    33
# 03/15/2017 09:24:00 AM    33
# 09/24/2018 07:44:00 PM    33
# 04/05/2018 05:59:00 PM    33
# 05/20/2019 10:18:00 AM    33
# 02/22/2018 10:28:00 AM    33
# Name: datetime_in, dtype: int64

# %%
lil_bit.datetime_out.value_counts()
# Out:
# 08/10/2019 11:56:00 AM    33
# 08/09/2018 11:13:00 AM    33
# 02/12/2019 03:20:00 PM    33
# 04/17/2018 11:07:00 AM    33
# 03/08/2018 03:04:00 PM    33
# 09/12/2016 01:40:00 PM    33
# 12/16/2016 11:32:00 AM    33
# 03/16/2017 12:50:00 PM    33
# 12/27/2018 03:41:00 PM    33
# 02/23/2018 01:06:00 PM    33
# 09/08/2018 01:55:00 PM    33
# 09/23/2018 02:22:00 PM    33
# 02/02/2017 11:19:00 AM    33
# 02/20/2016 04:18:00 PM    33
# 10/20/2019 11:35:00 AM    33
# 07/11/2016 05:44:00 PM    33
# 09/19/2019 11:02:00 AM    33
# 01/10/2017 04:20:00 PM    33
# 02/07/2017 05:26:00 PM    33
# 04/11/2018 12:37:00 PM    33
# 09/25/2018 06:14:00 PM    33
# 02/26/2019 07:00:00 PM    33
# 04/24/2018 04:12:00 PM    33
# 08/22/2018 01:21:00 PM    33
# 01/28/2017 03:22:00 PM    33
# 02/18/2019 04:46:00 PM    33
# 05/04/2019 08:37:00 AM    33
# 03/16/2018 04:04:00 PM    33
# 11/24/2018 04:25:00 PM    33
# 05/21/2019 02:42:00 PM    33
# 03/11/2019 04:27:00 PM    33
# 10/21/2016 06:55:00 PM    33
# 05/26/2018 03:52:00 PM    33
# Name: datetime_out, dtype: int64

# %%
lil_bit.found_location.value_counts()
# Out:
# 6210 E Ben White in Austin (TX)                           66
# 700 Allen St in Austin (TX)                               33
# South 1St And Stassney in Austin (TX)                     33
# 1500 Red River Street in Austin (TX)                      33
# 606 West Slaughter in Austin (TX)                         33
# 901 W Ben White Blvd in Austin (TX)                       33
# 6010 E Riverside in Austin (TX)                           33
# 6210 E Ben White Blvd in Austin (TX)                      33
# W Oltorf And S 1St St in Austin (TX)                      33
# Justin Lane And North Lamar in Austin (TX)                33
# 2508 E Riverside Dr in Austin (TX)                        33
# 9300 S Ih 35 in Austin (TX)                               33
# South First Street And Oltorf Street in Austin (TX)       33
# 1144 Airport in Austin (TX)                               33
# 1135 Airport Blvd in Austin (TX)                          33
# Austin (TX)                                               33
# 814 Stark Street in Austin (TX)                           33
# 4111 South 1St in Austin (TX)                             33
# 1500 Red River in Austin (TX)                             33
# East 7Th Street And Pleasant Valley in Austin (TX)        33
# S Pleasant Valley Rd And E Riverside Dr in Austin (TX)    33
# Burton And Oltorf in Austin (TX)                          33
# 6317 E Ben White Blvd in Austin (TX)                      33
# 1135 Airport Boulevard in Austin (TX)                     33
# 863 Airport Blvd in Austin (TX)                           33
# 6200 E. Ben White Blvd in Austin (TX)                     33
# 1936 East Oltorf Street in Austin (TX)                    33
# E Ben White Blvd & Montopolis Dr in Austin (TX)           33
# Shady And Airport in Austin (TX)                          33
# 9705 Manchaca Road in Austin (TX)                         33
# 1819 South Pleasant Valley Road in Austin (TX)            33
# 6400 Ben White Blvd in Austin (TX)                        33
# Name: found_location, dtype: int64

# %%
lil_bit.outcome_type.value_counts()
# Out:
# Return to Owner    1023
# Rto-Adopt            66
# Name: outcome_type, dtype: int64

# %% [markdown]
# ### Every intake time is being linked to every outcome time, so the amount of rows for return animals are squared of actual

# %%
(animals.color_in != animals.color_out).sum()
# Out:
# 0

# %% [markdown]
# ### color in is the same as color out for all animals

# %%
animals.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 193118 entries, 0 to 193117
# Data columns (total 23 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   animal_id         193118 non-null  object
#  1   name_in           148817 non-null  object
#  2   datetime_in       193118 non-null  object
#  3   monthyear_in      193118 non-null  object
#  4   found_location    193118 non-null  object
#  5   intake_type       193118 non-null  object
#  6   intake_condition  193118 non-null  object
#  7   animal_type_in    193118 non-null  object
#  8   sex_upon_intake   193116 non-null  object
#  9   age_upon_intake   193117 non-null  object
#  10  breed_in          193118 non-null  object
#  11  color_in          193118 non-null  object
#  12  name_out          148817 non-null  object
#  13  datetime_out      193118 non-null  object
#  14  monthyear_out     193118 non-null  object
#  15  date_of_birth     193118 non-null  object
#  16  outcome_type      193082 non-null  object
#  17  outcome_subtype   75665 non-null   object
#  18  animal_type_out   193118 non-null  object
#  19  sex_upon_outcome  193116 non-null  object
#  20  age_upon_outcome  193071 non-null  object
#  21  breed_out         193118 non-null  object
#  22  color_out         193118 non-null  object
# dtypes: object(23)
# memory usage: 35.4+ MB

# %%
(animals.breed_in != animals.breed_out).sum()
# Out:
# 0

# %% [markdown]
# #### Breed_in is the same as breed_out

# %%
(animals.name_in.isna() == animals.name_out.isna()).sum() / 193118
# Out:
# 1.0

# %%
(~animals.name_in.isna() == ~animals.name_out.isna()).sum() / 193118
# Out:
# 1.0

# %% [markdown]
# #### name_in is the same as name_out

# %%
animals = animals.drop(columns=['name_out'])
animals = animals.rename(columns={'name_in':'name'})

# %%
(animals.animal_type_in != animals.animal_type_out).sum()
# Out:
# 0

# %% [markdown]
# #### animal_type_in is the same as animal_type_out

# %%
animals = animals.drop(columns=['animal_type_out'])
animals = animals.rename(columns={'animal_type_in':'animal_type'})
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /var/folders/49/v6sf5vy165dghytk4qv6jfhc0000gn/T/ipykernel_1906/2850248451.py in <module>
# ----> 1 animals = animals.drop(columns=['animal_type_out'])
#       2 animals = animals.rename(columns={'animal_type_in':'animal_type'})
#
# /opt/anaconda3/lib/python3.9/site-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# /opt/anaconda3/lib/python3.9/site-packages/pandas/core/frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4955                 weight  1.0     0.8
#    4956         """
# -> 4957         return super().drop(
#    4958             labels=labels,
#    4959             axis=axis,
#
# /opt/anaconda3/lib/python3.9/site-packages/pandas/core/generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4265         for axis, labels in axes.items():
#    4266             if labels is not None:
# -> 4267                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    4268
#    4269         if inplace:
#
# /opt/anaconda3/lib/python3.9/site-packages/pandas/core/generic.py in _drop_axis(self, labels, axis, level, errors, consolidate, only_slice)
#    4309                 new_axis = axis.drop(labels, level=level, errors=errors)
#    4310             else:
# -> 4311                 new_axis = axis.drop(labels, errors=errors)
#    4312             indexer = axis.get_indexer(new_axis)
#    4313
#
# /opt/anaconda3/lib/python3.9/site-packages/pandas/core/indexes/base.py in drop(self, labels, errors)
#    6659         if mask.any():
#    6660             if errors != "ignore":
# -> 6661                 raise KeyError(f"{list(labels[mask])} not found in axis")
#    6662             indexer = indexer[~mask]
#    6663         return self.delete(indexer)
#
# KeyError: "['animal_type_out'] not found in axis"

# %%
animals = animals.drop(columns=['color_out', 'breed_out', 
                                'name_out', 'animal_type_out'])
animals = animals.rename(columns={'color_in':'color', 
                                  'breed_in':'breed', 'name_in':'name',
                                  'animal_type_in':'animal_type'})
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /var/folders/49/v6sf5vy165dghytk4qv6jfhc0000gn/T/ipykernel_1906/1129581173.py in <module>
# ----> 1 animals = animals.drop(columns=['color_out', 'breed_out', 'name_out'])
#       2 animals = animals.rename(columns={'color_in':'color',
#       3                                   'breed_in':'breed', 'name_in':'name'})
#       4 animals.info()
#
# /opt/anaconda3/lib/python3.9/site-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# /opt/anaconda3/lib/python3.9/site-packages/pandas/core/frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4955                 weight  1.0     0.8
#    4956         """
# -> 4957         return super().drop(
#    4958             labels=labels,
#    4959             axis=axis,
#
# /opt/anaconda3/lib/python3.9/site-packages/pandas/core/generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4265         for axis, labels in axes.items():
#    4266             if labels is not None:
# -> 4267                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    4268
#    4269         if inplace:
#
# /opt/anaconda3/lib/python3.9/site-packages/pandas/core/generic.py in _drop_axis(self, labels, axis, level, errors, consolidate, only_slice)
#    4309                 new_axis = axis.drop(labels, level=level, errors=errors)
#    4310             else:
# -> 4311                 new_axis = axis.drop(labels, errors=errors)
#    4312             indexer = axis.get_indexer(new_axis)
#    4313
#
# /opt/anaconda3/lib/python3.9/site-packages/pandas/core/indexes/base.py in drop(self, labels, errors)
#    6659         if mask.any():
#    6660             if errors != "ignore":
# -> 6661                 raise KeyError(f"{list(labels[mask])} not found in axis")
#    6662             indexer = indexer[~mask]
#    6663         return self.delete(indexer)
#
# KeyError: "['color_out', 'breed_out'] not found in axis"

# %%
animals.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 193118 entries, 0 to 193117
# Data columns (total 19 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   animal_id         193118 non-null  object
#  1   name              148817 non-null  object
#  2   datetime_in       193118 non-null  datetime64[ns]
#  3   monthyear_in      193118 non-null  object
#  4   found_location    193118 non-null  object
#  5   intake_type       193118 non-null  object
#  6   intake_condition  193118 non-null  object
#  7   animal_type       193118 non-null  object
#  8   sex_upon_intake   193116 non-null  object
#  9   age_upon_intake   193117 non-null  object
#  10  breed             193118 non-null  object
#  11  color             193118 non-null  object
#  12  datetime_out      193118 non-null  datetime64[ns]
#  13  monthyear_out     193118 non-null  object
#  14  date_of_birth     193118 non-null  object
#  15  outcome_type      193082 non-null  object
#  16  outcome_subtype   75665 non-null   object
#  17  sex_upon_outcome  193116 non-null  object
#  18  age_upon_outcome  193071 non-null  object
# dtypes: datetime64[ns](2), object(17)
# memory usage: 29.5+ MB

# %%
animals['datetime_in'] = pd.to_datetime(animals.datetime_in)
animals['datetime_out'] = pd.to_datetime(animals.datetime_out)

# %%
animals.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 193118 entries, 0 to 193117
# Data columns (total 20 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   animal_id         193118 non-null  object
#  1   name              148817 non-null  object
#  2   datetime_in       193118 non-null  datetime64[ns]
#  3   monthyear_in      193118 non-null  object
#  4   found_location    193118 non-null  object
#  5   intake_type       193118 non-null  object
#  6   intake_condition  193118 non-null  object
#  7   animal_type_in    193118 non-null  object
#  8   sex_upon_intake   193116 non-null  object
#  9   age_upon_intake   193117 non-null  object
#  10  breed             193118 non-null  object
#  11  color             193118 non-null  object
#  12  datetime_out      193118 non-null  datetime64[ns]
#  13  monthyear_out     193118 non-null  object
#  14  date_of_birth     193118 non-null  object
#  15  outcome_type      193082 non-null  object
#  16  outcome_subtype   75665 non-null   object
#  17  animal_type_out   193118 non-null  object
#  18  sex_upon_outcome  193116 non-null  object
#  19  age_upon_outcome  193071 non-null  object
# dtypes: datetime64[ns](2), object(18)
# memory usage: 30.9+ MB

# %%
animals.head()
# Out:
#   animal_id      name         datetime_in  monthyear_in  \
# 0   A665644       NaN 2013-10-21 07:59:00  October 2013
# 1   A665739    *Alana 2013-10-22 11:11:00  October 2013
# 2   A665763       NaN 2013-10-22 15:10:00  October 2013
# 3   A379998  Disciple 2013-10-23 11:42:00  October 2013
# 4   A634503     Otter 2013-10-01 14:49:00  October 2013
#
#                                  found_location      intake_type  \
# 0                                   Austin (TX)            Stray
# 1                                   Austin (TX)            Stray
# 2  E Riverside Dr/Royal Crest Dr in Austin (TX)            Stray
# 3                51St And Grover in Austin (TX)            Stray
# 4                                    Manor (TX)  Owner Surrender
#
#   intake_condition animal_type_in sex_upon_intake age_upon_intake  \
# 0             Sick            Cat   Intact Female         4 weeks
# 1           Normal            Cat   Intact Female         1 month
# 2           Normal            Dog     Intact Male        4 months
# 3           Normal            Dog     Intact Male        10 years
# 4           Normal            Dog   Spayed Female         2 years
#
#                       breed      color        datetime_out monthyear_out  \
# 0    Domestic Shorthair Mix     Calico 2013-10-21 11:39:00      Oct 2013
# 1  Domestic Medium Hair Mix      Black 2013-12-20 17:36:00      Dec 2013
# 2         Cairn Terrier Mix  Tan/White 2013-10-26 18:32:00      Oct 2013
# 3                  Pit Bull      Black 2013-10-25 12:53:00      Oct 2013
# 4       Norfolk Terrier Mix        Tan 2013-10-02 12:40:00      Oct 2013
#
#   date_of_birth     outcome_type outcome_subtype animal_type_out  \
# 0    09/21/2013         Transfer         Partner             Cat
# 1    09/16/2013         Adoption          Foster             Cat
# 2    06/22/2013         Adoption             NaN             Dog
# 3    02/21/2003  Return to Owner             NaN             Dog
# 4    08/11/2011         Adoption             NaN             Dog
#
#   sex_upon_outcome age_upon_outcome
# 0    Intact Female          4 weeks
# 1    Spayed Female         3 months
# 2    Neutered Male         4 months
# 3      Intact Male         10 years
# 4    Spayed Female          2 years

# %%
animals.outcome_subtype.value_counts()
# Out:
# Partner                39032
# Foster                 16298
# Rabies Risk             4383
# Suffering               3825
# Snr                     3528
# SCRP                    3507
# Out State               1057
# Aggressive               763
# In Kennel                758
# Offsite                  626
# In Foster                364
# Medical                  350
# At Vet                   337
# Field                    267
# Behavior                 186
# Enroute                   97
# Court/Investigation       94
# Underage                  37
# Possible Theft            34
# Customer S                30
# In Surgery                30
# Prc                       15
# Barn                      14
# Emergency                 14
# In State                  12
# Emer                       7
# Name: outcome_subtype, dtype: int64

# %%
animals.outcome_type.value_counts()
# Out:
# Adoption           91428
# Transfer           47153
# Return to Owner    40231
# Euthanasia         10118
# Rto-Adopt           1866
# Died                1448
# Disposal             698
# Missing              103
# Relocate              26
# Stolen                11
# Name: outcome_type, dtype: int64
